# %% [markdown]
# # Bayesian Knowledge Tracing (initial model)
#
# This notebook consists of a baseline BKT model as defined by Corbett & Anderson 1995. BKT aims to track student knowledge states for a given skill using underlying Hidden Markov Models, where the latent states are knowledge of a skill and observed states are correctness in answering questions related to that skill.
#
# Each skill will be represented as a BKT model with 4 parameters:
# * $p(L_0)$ or p_init_ : a priori knowledge of the skill (before any practice)
# * $p(T)$ or p_transit : probability of transitioning from the unknown to known state for that concept
# * $p(G)$ or p_guess : probability of answering a question correct if the skill is in the unknown state
# * $p(S)$ or p_slip : probability of answering a question wrong if the skill is in the known state
#
# And each student will have their own parameter subset $p(L_t)^k$ for each skill $k$ as they answer $t$ questions, which will be updated at each time point (question) $t$ per skill

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import time
import sklearn
from sklearn import metrics
import sys
sys.path.append('../')
from cf_matrix import make_confusion_matrix

# %% [markdown]
# ## Loading data:
#
# Loading all the dataframes here although I won't be looking at the lectures metadata for this model. Testing data will be used only for assessing model accuracy while training the models will use both the training and questions metadata.

# %%
# load data
data_dir = '../data/'

start = time.time()
df_train = pd.read_csv(data_dir + 'train.csv')
print('Training Data Loaded, time elapsed:', round(time.time() - start, 3), 'seconds')
df_lectures = pd.read_csv(data_dir + 'lectures.csv')
df_questions = pd.read_csv(data_dir + 'questions.csv')
#df_test = pd.read_csv(data_dir + 'example_test.csv')

print('All Dataframes Loaded ------------------------------')
# Out:
# Training Data Loaded, time elapsed: 95.398 seconds
# All Dataframes Loaded ------------------------------

# %% [markdown]
# ### Viewing initial dataframes

# %%
df_train
# Out:
#               row_id  timestamp     user_id  content_id  content_type_id  \
# 0                  0          0         115        5692                0
# 1                  1      56943         115        5716                0
# 2                  2     118363         115         128                0
# 3                  3     131167         115        7860                0
# 4                  4     137965         115        7922                0
# ...              ...        ...         ...         ...              ...
# 101230327  101230327  428564420  2147482888        3586                0
# 101230328  101230328  428585000  2147482888        6341                0
# 101230329  101230329  428613475  2147482888        4212                0
# 101230330  101230330  428649406  2147482888        6343                0
# 101230331  101230331  428692118  2147482888        7995                0
#
#            task_container_id  user_answer  answered_correctly  \
# 0                          1            3                   1
# 1                          2            2                   1
# 2                          0            0                   1
# 3                          3            0                   1
# 4                          4            1                   1
# ...                      ...          ...                 ...
# 101230327                 22            0                   1
# 101230328                 23            3                   1
# 101230329                 24            3                   1
# 101230330                 25            1                   0
# 101230331                 26            3                   1
#
#            prior_question_elapsed_time prior_question_had_explanation
# 0                                  NaN                            NaN
# 1                              37000.0                          False
# 2                              55000.0                          False
# 3                              19000.0                          False
# 4                              11000.0                          False
# ...                                ...                            ...
# 101230327                      18000.0                           True
# 101230328                      14000.0                           True
# 101230329                      14000.0                           True
# 101230330                      22000.0                           True
# 101230331                      29000.0                           True
#
# [101230332 rows x 10 columns]

# %%
df_questions
# Out:
#        question_id  bundle_id  correct_answer  part            tags
# 0                0          0               0     1   51 131 162 38
# 1                1          1               1     1       131 36 81
# 2                2          2               0     1  131 101 162 92
# 3                3          3               0     1  131 149 162 29
# 4                4          4               3     1    131 5 162 38
# ...            ...        ...             ...   ...             ...
# 13518        13518      13518               3     5              14
# 13519        13519      13519               3     5               8
# 13520        13520      13520               2     5              73
# 13521        13521      13521               0     5             125
# 13522        13522      13522               3     5              55
#
# [13523 rows x 5 columns]

# %% [markdown]
# ### Cleaning

# %%
# dropping unneeded columns from train
dropcols = ['row_id', 'task_container_id', 'prior_question_elapsed_time', 'prior_question_had_explanation']
df_train.drop(dropcols, axis=1, inplace=True)

# %%
# since we aren't looking at lectures, I'm restricting training data to exclude lectures (content_type_id = 1)
print('Dropping {} rows...'.format(len(df_train[df_train['content_type_id'] == 1])))
df_train = df_train[df_train['content_type_id'] == 0]
# Out:
# Dropping 1959032 rows...

# %%
# can drop content_type_id now because they're all the same value (0)
df_train.drop('content_type_id', axis=1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# dropping bundle_id and part from questions
# bundle_id represents which questions are shown together and may be used for future modifications of the model,
#  but different bundles don't seem to correspond to different tags so I won't use them here
# part corresponds to a higher level type of question ranging rom 1-5 that are too broad for this analysis
dropcols = ['bundle_id', 'part']
df_questions.drop(dropcols, axis=1, inplace=True)

# %%
# changing 'tags' column to a list structure so its easier to query later on and setting null value to -1
df_questions['tags'].fillna('-1', inplace=True)
df_questions['tags'] = df_questions['tags'].str.split()

# %% [markdown]
# ### Viewing cleaned dataframes

# %%
df_train
# Out:
#            timestamp     user_id  content_id  user_answer  answered_correctly
# 0                  0         115        5692            3                   1
# 1              56943         115        5716            2                   1
# 2             118363         115         128            0                   1
# 3             131167         115        7860            0                   1
# 4             137965         115        7922            1                   1
# ...              ...         ...         ...          ...                 ...
# 101230327  428564420  2147482888        3586            0                   1
# 101230328  428585000  2147482888        6341            3                   1
# 101230329  428613475  2147482888        4212            3                   1
# 101230330  428649406  2147482888        6343            1                   0
# 101230331  428692118  2147482888        7995            3                   1
#
# [99271300 rows x 5 columns]

# %%
df_questions
# Out:
#        question_id  correct_answer                 tags
# 0                0               0   [51, 131, 162, 38]
# 1                1               1        [131, 36, 81]
# 2                2               0  [131, 101, 162, 92]
# 3                3               0  [131, 149, 162, 29]
# 4                4               3    [131, 5, 162, 38]
# ...            ...             ...                  ...
# 13518        13518               3                 [14]
# 13519        13519               3                  [8]
# 13520        13520               2                 [73]
# 13521        13521               0                [125]
# 13522        13522               3                 [55]
#
# [13523 rows x 3 columns]

# %% [markdown]
# ### Splitting train/test sets
#
# This is necessary because the test set given (df_test) does not actually provide the true labels of student answers, thus impossible to get accuracy from. I will split the training set (df_train) into training and testing sets, where the test set will be ~1mil rows (~1% of training), and such a small test set should be fine given the size of training data. Since this is essentially time series calculations, the test set will be comprised of the last rows of each user (randomly select 1-5 rows for each user) rather than randomly splitting the training set.

# %%
df_test = pd.DataFrame()
start = time.time()
for i,user in enumerate(df_train['user_id'].unique()):
    df_test = pd.concat([df_test,df_train[df_train['user_id'] == user][-1 - np.random.randint(4):]])
    if i % 10000 == 0:
        print('user {} done.........time elapsed: {} seconds'.format(i, time.time() - start))
        start = time.time()
# Out:
# user 0 done.........time elapsed: 0.48099207878112793 seconds
# user 10000 done.........time elapsed: 955.3037340641022 seconds
# user 20000 done.........time elapsed: 929.7716600894928 seconds
# user 30000 done.........time elapsed: 928.8658649921417 seconds
# user 40000 done.........time elapsed: 940.0345618724823 seconds
# user 50000 done.........time elapsed: 936.2491569519043 seconds
# user 60000 done.........time elapsed: 940.6341998577118 seconds
# user 70000 done.........time elapsed: 948.4981298446655 seconds
# user 80000 done.........time elapsed: 960.1756911277771 seconds
# user 90000 done.........time elapsed: 958.7641141414642 seconds
# user 100000 done.........time elapsed: 961.5525588989258 seconds
# user 110000 done.........time elapsed: 967.5787811279297 seconds
# user 120000 done.........time elapsed: 972.3550961017609 seconds
# user 130000 done.........time elapsed: 977.6888949871063 seconds
# user 140000 done.........time elapsed: 983.0202059745789 seconds
# user 150000 done.........time elapsed: 988.3505549430847 seconds
# user 160000 done.........time elapsed: 997.076073884964 seconds
# user 170000 done.........time elapsed: 996.4307601451874 seconds
# user 180000 done.........time elapsed: 1003.4130139350891 seconds
# user 190000 done.........time elapsed: 1010.0248172283173 seconds
# user 200000 done.........time elapsed: 1009.3731248378754 seconds
# user 210000 done.........time elapsed: 1017.2041397094727 seconds
# user 220000 done.........time elapsed: 1023.1832871437073 seconds
# user 230000 done.........time elapsed: 1026.6471588611603 seconds
# user 240000 done.........time elapsed: 1030.5455839633942 seconds
# user 250000 done.........time elapsed: 1034.5127851963043 seconds
# user 260000 done.........time elapsed: 1040.5546629428864 seconds
# user 270000 done.........time elapsed: 1020.2820122241974 seconds
# user 280000 done.........time elapsed: 1020.1859200000763 seconds
# user 290000 done.........time elapsed: 1024.2327508926392 seconds
# user 300000 done.........time elapsed: 1028.4382710456848 seconds
# user 310000 done.........time elapsed: 1032.6858632564545 seconds
# user 320000 done.........time elapsed: 1036.0662009716034 seconds
# user 330000 done.........time elapsed: 1041.3184430599213 seconds
# user 340000 done.........time elapsed: 1045.6828651428223 seconds
# user 350000 done.........time elapsed: 1048.6387860774994 seconds
# user 360000 done.........time elapsed: 1061.1100957393646 seconds
# user 370000 done.........time elapsed: 1102.1675610542297 seconds
# user 380000 done.........time elapsed: 1166.1223437786102 seconds
# user 390000 done.........time elapsed: 1183.2604291439056 seconds

# %%
# dropping rows from training set
df_train.drop(df_test.index, inplace=True, axis=0)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# reset indeces and save to csv file
df_train.reset_index(inplace=True, drop=True)
df_test.reset_index(inplace=True, drop=True)

df_train.to_csv('df_train2.0.csv')
df_test.to_csv('df_test2.0.csv')

# %%
df_train
# Out:
#           timestamp     user_id  content_id  user_answer  answered_correctly
# 0                 0         115        5692            3                   1
# 1             56943         115        5716            2                   1
# 2            118363         115         128            0                   1
# 3            131167         115        7860            0                   1
# 4            137965         115        7922            1                   1
# ...             ...         ...         ...          ...                 ...
# 98287376  428466169  2147482888        5591            3                   1
# 98287377  428517313  2147482888        6128            1                   1
# 98287378  428542872  2147482888        6202            2                   1
# 98287379  428564420  2147482888        3586            0                   1
# 98287380  428585000  2147482888        6341            3                   1
#
# [98287381 rows x 5 columns]

# %%
df_test
# Out:
#          timestamp     user_id  content_id  user_answer  answered_correctly
# 0        668090043         115        3363            1                   0
# 1        668090043         115        3365            0                   0
# 2        668090043         115        3364            1                   1
# 3           571323         124        7218            3                   0
# 4           571323         124        7216            0                   0
# ...            ...         ...         ...          ...                 ...
# 983914  1470571968  2147482216        1177            3                   1
# 983915  1470594073  2147482216        1399            1                   1
# 983916   428613475  2147482888        4212            3                   1
# 983917   428649406  2147482888        6343            1                   0
# 983918   428692118  2147482888        7995            3                   1
#
# [983919 rows x 5 columns]

# %% [markdown]
# ## Fitting skill parameters
#
# There seems to be a few ways in the literature about how one can do this: EM, brute-force search, and conjugate gradient search have all been done. Here, I've chosen to use the **Empirical Probabilities** approach as defined in Hawkins, Heffernan, and Baker 2011, where they shown that this way of initializing the model parameters resulted in statistically significant increase in model performance.
#
# In this model the skill parameters will not change with training and will remain constant across time and students...future direction will include accounting for student-specific parameters and potentially modifying those parameters as needed for training.
#
# ### Computing knowledge sequences
#
# The first step in the empirical probabilities approach to fitting skill parameters is to compute 'knowledge sequences' for each skill for each student. I am treating each separate 'tag' as its own skill, and questions that have multiple tags will count towards the knowledge sequences for all of the tags.
#
# Additionally for each skill, each student has their own knowledge sequence and all the knowledge sequences for a skill will be used to calculate that skill's BKT parameters

# %%
def get_knowledge_sequence(response):
    """
    Given a list of student responses to questions within a skill, this function computes the 
    knowledge sequence defined by Hawkins et al. (2011)
    This function (1) computes all knowledge permuatations of the length of the student's responses, where
    these permutations have the condition that a wrong answer cannot come after a right answer (no forgetting), 
    then (2) matches the responses to the permutation that's most similar and returns that sequence.
    If there is a tie, the average is taken
    
    Parameters
    ----------
    responses: sequence of student's answers to questions (correct/incorrect) as binary sequence
    
    Returns
    -------
    sequence: binary knowledge sequence where change from 0->1 signifies transition to learned state
    
    """
    l = len(response)
    maxs = []
    maxacc = 0
    
    def accuracy(resp, perm):
        """Get accuracy of student response and a given permutation"""
        unit = 1 / l
        acc = 0
        for i in range(l):
            if resp[i] == perm[i]:
                acc += unit
        return acc
    
    for i in range(l+1):
        perm = ([0] * (l-i)) + ([1] * i)
        if accuracy(response, perm) > maxacc:
            maxacc = accuracy(response, perm)
            maxs = [perm]
        elif accuracy(response, perm) == maxacc:
            maxs.append(perm)
    
    if len(maxs) == 1:
        return maxs[0]
    else:
        maxs = np.array(maxs)
        return list(maxs.mean(axis=0))

# %%
def get_all_sequences(df_train):
    """
    Function to get all of the knowledge sequences given the training data by going through each student
    and recording correctness to answers in each skill (tag), then calls get_knowledge_sequence to compute
    the knowledge sequences for each skill
    
    Params
    -------
    df_train : training dataframe
    
    Returns
    --------
    responses : raw correct/incorrect sequences for each skill
    sequences : dict of knowledge sequences per skill, where keys are a skill and values are a list of 
                knowledge sequences for that skill (1 per student who was tested on the skill)
    """
    print('TOTAL USERS: {}'.format(len(df_train['user_id'].unique())))
    start = time.time()
    
    # construct student responses for each tag
    responses = dict() # correctness (binary) scores
    sequences = dict() # knowledge sequences
    for n,user in enumerate(df_train['user_id'].unique()):

        # for each interaction of this user
        stuseentags = [] # tags that students has a running score for
        for i,row in df_train[df_train['user_id'] == user].sort_values(by='timestamp').iterrows():
            tags = df_questions.loc[df_questions['question_id'] == row['content_id'], 'tags'].values[0]

            for t in tags:
                responses[t] = responses.get(t, []) # initializes a list if its a new tag
                if t not in stuseentags:
                    stuseentags.append(t)
                    responses[t].append([row['answered_correctly']])
                else:
                    responses[t][-1].append(row['answered_correctly'])
                    
        for tag in stuseentags:
            sequences[tag] = sequences.get(tag, [])
            sequences[tag].append(get_knowledge_sequence(responses[tag][-1]))
        
        if n % 50 == 0:
            print('USER {} COMPLETED----------------\tTime Elapsed: {} seconds'.format(n, time.time() - start))
            start = time.time()
            #break
    
    return responses,sequences

# %% [markdown]
# ### Fitting parameters to each skill
#
# Given the responses and knowledge sequences, I'm going to fit the parameters for each skill using the following equations (as given by Hawkins 2011):
#
# $$p(L_0) = \frac{\sum{K_0}}{|K_0|}$$
#
#
# $$p(T) = \frac{\sum_{i!=0}{(1-K_{i-1})}K_i}{\sum_{i!=0}{(1-K_{i-1})}}$$
#
#
# $$p(G) = \frac{\sum_iC_i(1-K_i)}{\sum_i (1-K_i)}$$
#
#
# $$p(S) = \frac{\sum_i (1-C_i)K_i}{\sum_i K_i}$$

# %%
### CALL THIS FUNCTION TO FIT PARAMS, ALL OTHER FUNCS ARE ENCAPSULATED IN HERE ############
###########################################################################################
## DO NOT DO NOT DO NOT CALL THIS FUNCTION AGAIN -- PARAMS ARE STORED IN JSON FILE ######## 
######## FUNCTION MODIFIED TO RANDOML SELECT 10% OF STUDENTS TO FIT PARAMS TO #############
###########################################################################################
def fit_params_EP(df_train, fit_subset):
    """
    Wrapper function to fit parameters, calls all other functions necessary and then computes 4 parameters
    per skill using the Empirical Probabilities method (Hawkins 2011)
    
    Parameters
    ---------
    df_train : training dataframe to work with
    fit_subset : subset of training data to fit parameters to (saving computation) - must be (0.1]
    
    Returns
    --------
    params :  dict where keys are skill tags, values are a dict of the 4 parameters 
                    (p_init, p_transit, p_guess, p_slip)
    """
    
    random_users = []
    for user in df_train['user_id'].unique():
        rand = np.random.rand()
        if rand < fit_subset:
            random_users.append(user)
    df_train = df_train[df_train['user_id'].isin(random_users)]
    
    C, K = get_all_sequences(df_train)
    
    params = dict()
    for key in C.keys():
        p = dict()

        p['p_init'] = sum([i[0] for i in K[key]]) / len(K[key])

        pt_n, pt_d = 0,0
        pg_n, pg_d = 0,0
        ps_n, ps_d = 0,0

        for i in range(len(max(K[key], key=len))):
            for seq in range(len(K[key])):
                if len(K[key][seq]) <= i:
                    continue
                if i > 0:
                    pt_n += (1-K[key][seq][i-1]) * K[key][seq][i]
                    pt_d += (1-K[key][seq][i-1])
                pg_n += C[key][seq][i] * (1-K[key][seq][i])
                pg_d += 1-K[key][seq][i]
                ps_n += (1-C[key][seq][i]) * K[key][seq][i]
                ps_d += K[key][seq][i]

        p['p_transit'] = pt_n / pt_d if pt_d != 0 else 0
        p['p_guess'] = pg_n / pg_d if pg_d != 0 else 0
        p['p_slip'] = ps_n / ps_d if pg_d != 0 else 0

        params[key] = p
    
    return params

# %%
# DON'T RUN THIS AGAIN, PARAMS ARE STORED IN JSON FILE LOOK AT CELL BELOW
params = fit_params_EP(df_train, fit_subset = 0.1)

# save params to json
with open('skill_params.json', 'w') as json_file:
    json.dump(params, json_file)
# Out:
# TOTAL USERS: 98674
# USER 0 COMPLETED----------------	Time Elapsed: 0.8609552383422852 seconds
# USER 50 COMPLETED----------------	Time Elapsed: 21.69304609298706 seconds
# USER 100 COMPLETED----------------	Time Elapsed: 8.466467142105103 seconds
# USER 150 COMPLETED----------------	Time Elapsed: 7.858684778213501 seconds
# USER 200 COMPLETED----------------	Time Elapsed: 12.421921014785767 seconds
# USER 250 COMPLETED----------------	Time Elapsed: 9.520145893096924 seconds
# USER 300 COMPLETED----------------	Time Elapsed: 9.817832946777344 seconds
# USER 350 COMPLETED----------------	Time Elapsed: 5.988971948623657 seconds
# USER 400 COMPLETED----------------	Time Elapsed: 6.974249839782715 seconds
# USER 450 COMPLETED----------------	Time Elapsed: 4.56501317024231 seconds
# USER 500 COMPLETED----------------	Time Elapsed: 12.743934869766235 seconds
# USER 550 COMPLETED----------------	Time Elapsed: 9.217548847198486 seconds
# USER 600 COMPLETED----------------	Time Elapsed: 5.557308912277222 seconds
# USER 650 COMPLETED----------------	Time Elapsed: 8.147555112838745 seconds
# USER 700 COMPLETED----------------	Time Elapsed: 5.935266017913818 seconds
# USER 750 COMPLETED----------------	Time Elapsed: 16.371879816055298 seconds
# USER 800 COMPLETED----------------	Time Elapsed: 7.872366189956665 seconds
# USER 850 COMPLETED----------------	Time Elapsed: 4.499849081039429 seconds
# USER 900 COMPLETED----------------	Time Elapsed: 4.605449914932251 seconds
# USER 950 COMPLETED----------------	Time Elapsed: 5.7892186641693115 seconds
# USER 1000 COMPLETED----------------	Time Elapsed: 7.317022085189819 seconds
# USER 1050 COMPLETED----------------	Time Elapsed: 10.261826992034912 seconds
# USER 1100 COMPLETED----------------	Time Elapsed: 4.057784795761108 seconds
# USER 1150 COMPLETED----------------	Time Elapsed: 5.319511890411377 seconds
# USER 1200 COMPLETED----------------	Time Elapsed: 6.882591009140015 seconds
# USER 1250 COMPLETED----------------	Time Elapsed: 6.5288190841674805 seconds
# USER 1300 COMPLETED----------------	Time Elapsed: 5.34382176399231 seconds
# USER 1350 COMPLETED----------------	Time Elapsed: 3.2050938606262207 seconds
# USER 1400 COMPLETED----------------	Time Elapsed: 4.537630796432495 seconds
# USER 1450 COMPLETED----------------	Time Elapsed: 19.496243238449097 seconds
# USER 1500 COMPLETED----------------	Time Elapsed: 8.28548288345337 seconds
# USER 1550 COMPLETED----------------	Time Elapsed: 10.929094791412354 seconds
# USER 1600 COMPLETED----------------	Time Elapsed: 8.086174011230469 seconds
# USER 1650 COMPLETED----------------	Time Elapsed: 5.606558084487915 seconds
# USER 1700 COMPLETED----------------	Time Elapsed: 9.354323148727417 seconds
# USER 1750 COMPLETED----------------	Time Elapsed: 5.9565269947052 seconds
# USER 1800 COMPLETED----------------	Time Elapsed: 11.896698236465454 seconds
# USER 1850 COMPLETED----------------	Time Elapsed: 10.247759819030762 seconds
# USER 1900 COMPLETED----------------	Time Elapsed: 22.232501983642578 seconds
# USER 1950 COMPLETED----------------	Time Elapsed: 5.144680023193359 seconds
# USER 2000 COMPLETED----------------	Time Elapsed: 6.307855844497681 seconds
# USER 2050 COMPLETED----------------	Time Elapsed: 7.461993932723999 seconds
# USER 2100 COMPLETED----------------	Time Elapsed: 5.319039821624756 seconds
# USER 2150 COMPLETED----------------	Time Elapsed: 8.434895753860474 seconds
# USER 2200 COMPLETED----------------	Time Elapsed: 6.668837308883667 seconds
# USER 2250 COMPLETED----------------	Time Elapsed: 8.420948028564453 seconds
# USER 2300 COMPLETED----------------	Time Elapsed: 2.919361114501953 seconds
# USER 2350 COMPLETED----------------	Time Elapsed: 7.684064149856567 seconds
# USER 2400 COMPLETED----------------	Time Elapsed: 5.5597710609436035 seconds
# USER 2450 COMPLETED----------------	Time Elapsed: 3.6959009170532227 seconds
# USER 2500 COMPLETED----------------	Time Elapsed: 6.249715089797974 seconds
# USER 2550 COMPLETED----------------	Time Elapsed: 8.529102087020874 seconds
# USER 2600 COMPLETED----------------	Time Elapsed: 8.539465188980103 seconds
# USER 2650 COMPLETED----------------	Time Elapsed: 5.289893865585327 seconds
# USER 2700 COMPLETED----------------	Time Elapsed: 8.968232870101929 seconds
# USER 2750 COMPLETED----------------	Time Elapsed: 8.967989921569824 seconds
# USER 2800 COMPLETED----------------	Time Elapsed: 9.949622869491577 seconds
# USER 2850 COMPLETED----------------	Time Elapsed: 15.024180889129639 seconds
# USER 2900 COMPLETED----------------	Time Elapsed: 9.111708164215088 seconds
# USER 2950 COMPLETED----------------	Time Elapsed: 29.456723928451538 seconds
# USER 3000 COMPLETED----------------	Time Elapsed: 8.799443006515503 seconds
# USER 3050 COMPLETED----------------	Time Elapsed: 9.50052285194397 seconds
# USER 3100 COMPLETED----------------	Time Elapsed: 10.192854166030884 seconds
# USER 3150 COMPLETED----------------	Time Elapsed: 3.471534013748169 seconds
# USER 3200 COMPLETED----------------	Time Elapsed: 4.681023836135864 seconds
# USER 3250 COMPLETED----------------	Time Elapsed: 5.687648057937622 seconds
# USER 3300 COMPLETED----------------	Time Elapsed: 15.550957918167114 seconds
# USER 3350 COMPLETED----------------	Time Elapsed: 4.237545967102051 seconds
# USER 3400 COMPLETED----------------	Time Elapsed: 10.006194829940796 seconds
# USER 3450 COMPLETED----------------	Time Elapsed: 6.578190088272095 seconds
# USER 3500 COMPLETED----------------	Time Elapsed: 6.971548080444336 seconds
# USER 3550 COMPLETED----------------	Time Elapsed: 4.958775997161865 seconds
# USER 3600 COMPLETED----------------	Time Elapsed: 7.020326852798462 seconds
# USER 3650 COMPLETED----------------	Time Elapsed: 21.886098861694336 seconds
# USER 3700 COMPLETED----------------	Time Elapsed: 26.680426120758057 seconds
# USER 3750 COMPLETED----------------	Time Elapsed: 18.78629779815674 seconds
# USER 3800 COMPLETED----------------	Time Elapsed: 8.730261087417603 seconds
# USER 3850 COMPLETED----------------	Time Elapsed: 31.131650924682617 seconds
# USER 3900 COMPLETED----------------	Time Elapsed: 6.870476961135864 seconds
# USER 3950 COMPLETED----------------	Time Elapsed: 9.337840795516968 seconds
# USER 4000 COMPLETED----------------	Time Elapsed: 6.6807541847229 seconds
# USER 4050 COMPLETED----------------	Time Elapsed: 8.9566810131073 seconds
# USER 4100 COMPLETED----------------	Time Elapsed: 15.88654375076294 seconds
# USER 4150 COMPLETED----------------	Time Elapsed: 5.862416744232178 seconds
# USER 4200 COMPLETED----------------	Time Elapsed: 10.226049900054932 seconds
# USER 4250 COMPLETED----------------	Time Elapsed: 6.088275909423828 seconds
# USER 4300 COMPLETED----------------	Time Elapsed: 3.6316030025482178 seconds
# USER 4350 COMPLETED----------------	Time Elapsed: 9.90304684638977 seconds
# USER 4400 COMPLETED----------------	Time Elapsed: 6.107186794281006 seconds
# USER 4450 COMPLETED----------------	Time Elapsed: 5.844095945358276 seconds
# USER 4500 COMPLETED----------------	Time Elapsed: 6.980006217956543 seconds
# USER 4550 COMPLETED----------------	Time Elapsed: 5.081708908081055 seconds
# USER 4600 COMPLETED----------------	Time Elapsed: 8.719000816345215 seconds
# USER 4650 COMPLETED----------------	Time Elapsed: 4.497615814208984 seconds
# USER 4700 COMPLETED----------------	Time Elapsed: 5.894495010375977 seconds
# USER 4750 COMPLETED----------------	Time Elapsed: 8.731235027313232 seconds
# USER 4800 COMPLETED----------------	Time Elapsed: 4.521371841430664 seconds
# USER 4850 COMPLETED----------------	Time Elapsed: 4.668759107589722 seconds
# USER 4900 COMPLETED----------------	Time Elapsed: 4.52662992477417 seconds
# USER 4950 COMPLETED----------------	Time Elapsed: 4.767668962478638 seconds
# USER 5000 COMPLETED----------------	Time Elapsed: 7.869842290878296 seconds
# USER 5050 COMPLETED----------------	Time Elapsed: 9.765422821044922 seconds
# USER 5100 COMPLETED----------------	Time Elapsed: 7.622162342071533 seconds
# USER 5150 COMPLETED----------------	Time Elapsed: 45.38688778877258 seconds
# USER 5200 COMPLETED----------------	Time Elapsed: 4.334272623062134 seconds
# USER 5250 COMPLETED----------------	Time Elapsed: 9.346155881881714 seconds
# USER 5300 COMPLETED----------------	Time Elapsed: 5.8836729526519775 seconds
# USER 5350 COMPLETED----------------	Time Elapsed: 14.25933313369751 seconds
# USER 5400 COMPLETED----------------	Time Elapsed: 19.780582904815674 seconds
# USER 5450 COMPLETED----------------	Time Elapsed: 6.373633861541748 seconds
# USER 5500 COMPLETED----------------	Time Elapsed: 14.684442043304443 seconds
# USER 5550 COMPLETED----------------	Time Elapsed: 5.878988027572632 seconds
# USER 5600 COMPLETED----------------	Time Elapsed: 4.353982925415039 seconds
# USER 5650 COMPLETED----------------	Time Elapsed: 12.585348844528198 seconds
# USER 5700 COMPLETED----------------	Time Elapsed: 6.78955602645874 seconds
# USER 5750 COMPLETED----------------	Time Elapsed: 5.6244001388549805 seconds
# USER 5800 COMPLETED----------------	Time Elapsed: 11.356452941894531 seconds
# USER 5850 COMPLETED----------------	Time Elapsed: 6.689164638519287 seconds
# USER 5900 COMPLETED----------------	Time Elapsed: 15.497756004333496 seconds
# USER 5950 COMPLETED----------------	Time Elapsed: 12.058413982391357 seconds
# USER 6000 COMPLETED----------------	Time Elapsed: 8.140692949295044 seconds
# USER 6050 COMPLETED----------------	Time Elapsed: 8.196327209472656 seconds
# USER 6100 COMPLETED----------------	Time Elapsed: 25.355489015579224 seconds
# USER 6150 COMPLETED----------------	Time Elapsed: 5.834432125091553 seconds
# USER 6200 COMPLETED----------------	Time Elapsed: 9.545762777328491 seconds
# USER 6250 COMPLETED----------------	Time Elapsed: 5.191972255706787 seconds
# USER 6300 COMPLETED----------------	Time Elapsed: 5.740262269973755 seconds
# USER 6350 COMPLETED----------------	Time Elapsed: 4.517781019210815 seconds
# USER 6400 COMPLETED----------------	Time Elapsed: 7.390377998352051 seconds
# USER 6450 COMPLETED----------------	Time Elapsed: 5.919337034225464 seconds
# USER 6500 COMPLETED----------------	Time Elapsed: 4.711609125137329 seconds
# USER 6550 COMPLETED----------------	Time Elapsed: 5.67592978477478 seconds
# USER 6600 COMPLETED----------------	Time Elapsed: 4.524308919906616 seconds
# USER 6650 COMPLETED----------------	Time Elapsed: 3.83199405670166 seconds
# USER 6700 COMPLETED----------------	Time Elapsed: 14.332623720169067 seconds
# USER 6750 COMPLETED----------------	Time Elapsed: 16.965739011764526 seconds
# USER 6800 COMPLETED----------------	Time Elapsed: 9.439517259597778 seconds
# USER 6850 COMPLETED----------------	Time Elapsed: 21.090919733047485 seconds
# USER 6900 COMPLETED----------------	Time Elapsed: 6.705942869186401 seconds
# USER 6950 COMPLETED----------------	Time Elapsed: 8.714591979980469 seconds
# USER 7000 COMPLETED----------------	Time Elapsed: 8.828032970428467 seconds
# USER 7050 COMPLETED----------------	Time Elapsed: 5.076868772506714 seconds
# USER 7100 COMPLETED----------------	Time Elapsed: 18.390654802322388 seconds
# USER 7150 COMPLETED----------------	Time Elapsed: 13.014163970947266 seconds
# USER 7200 COMPLETED----------------	Time Elapsed: 6.646295070648193 seconds
# USER 7250 COMPLETED----------------	Time Elapsed: 6.501024961471558 seconds
# USER 7300 COMPLETED----------------	Time Elapsed: 5.978150367736816 seconds
# USER 7350 COMPLETED----------------	Time Elapsed: 5.154829978942871 seconds
# USER 7400 COMPLETED----------------	Time Elapsed: 12.49156403541565 seconds
# USER 7450 COMPLETED----------------	Time Elapsed: 12.310243844985962 seconds
# USER 7500 COMPLETED----------------	Time Elapsed: 10.371541976928711 seconds
# USER 7550 COMPLETED----------------	Time Elapsed: 5.942840814590454 seconds
# USER 7600 COMPLETED----------------	Time Elapsed: 12.682708024978638 seconds
# USER 7650 COMPLETED----------------	Time Elapsed: 7.561254978179932 seconds
# USER 7700 COMPLETED----------------	Time Elapsed: 8.66820764541626 seconds
# USER 7750 COMPLETED----------------	Time Elapsed: 9.88190221786499 seconds
# USER 7800 COMPLETED----------------	Time Elapsed: 8.327635049819946 seconds
# USER 7850 COMPLETED----------------	Time Elapsed: 10.294778823852539 seconds
# USER 7900 COMPLETED----------------	Time Elapsed: 7.533944845199585 seconds
# USER 7950 COMPLETED----------------	Time Elapsed: 11.805595874786377 seconds
# USER 8000 COMPLETED----------------	Time Elapsed: 5.746649980545044 seconds
# USER 8050 COMPLETED----------------	Time Elapsed: 8.331836938858032 seconds
# USER 8100 COMPLETED----------------	Time Elapsed: 6.896451950073242 seconds
# USER 8150 COMPLETED----------------	Time Elapsed: 11.212926149368286 seconds
# USER 8200 COMPLETED----------------	Time Elapsed: 10.15851902961731 seconds
# USER 8250 COMPLETED----------------	Time Elapsed: 4.896342992782593 seconds
# USER 8300 COMPLETED----------------	Time Elapsed: 11.816049337387085 seconds
# USER 8350 COMPLETED----------------	Time Elapsed: 7.161175966262817 seconds
# USER 8400 COMPLETED----------------	Time Elapsed: 7.625267028808594 seconds
# USER 8450 COMPLETED----------------	Time Elapsed: 12.200163841247559 seconds
# USER 8500 COMPLETED----------------	Time Elapsed: 5.743366003036499 seconds
# USER 8550 COMPLETED----------------	Time Elapsed: 4.6470887660980225 seconds
# USER 8600 COMPLETED----------------	Time Elapsed: 3.5271761417388916 seconds
# USER 8650 COMPLETED----------------	Time Elapsed: 5.474189043045044 seconds
# USER 8700 COMPLETED----------------	Time Elapsed: 6.3778159618377686 seconds
# USER 8750 COMPLETED----------------	Time Elapsed: 12.945439100265503 seconds
# USER 8800 COMPLETED----------------	Time Elapsed: 7.873699188232422 seconds
# USER 8850 COMPLETED----------------	Time Elapsed: 4.24370002746582 seconds
# USER 8900 COMPLETED----------------	Time Elapsed: 23.162358045578003 seconds
# USER 8950 COMPLETED----------------	Time Elapsed: 6.599699020385742 seconds
# USER 9000 COMPLETED----------------	Time Elapsed: 7.103755950927734 seconds
# USER 9050 COMPLETED----------------	Time Elapsed: 7.8187689781188965 seconds
# USER 9100 COMPLETED----------------	Time Elapsed: 6.125831127166748 seconds
# USER 9150 COMPLETED----------------	Time Elapsed: 9.829214811325073 seconds
# USER 9200 COMPLETED----------------	Time Elapsed: 7.430485010147095 seconds
# USER 9250 COMPLETED----------------	Time Elapsed: 6.093131065368652 seconds
# USER 9300 COMPLETED----------------	Time Elapsed: 6.5677361488342285 seconds
# USER 9350 COMPLETED----------------	Time Elapsed: 5.48416805267334 seconds
# USER 9400 COMPLETED----------------	Time Elapsed: 5.135272264480591 seconds
# USER 9450 COMPLETED----------------	Time Elapsed: 9.650315999984741 seconds
# USER 9500 COMPLETED----------------	Time Elapsed: 36.139785051345825 seconds
# USER 9550 COMPLETED----------------	Time Elapsed: 5.704608201980591 seconds
# USER 9600 COMPLETED----------------	Time Elapsed: 12.965285301208496 seconds
# USER 9650 COMPLETED----------------	Time Elapsed: 4.791733980178833 seconds
# USER 9700 COMPLETED----------------	Time Elapsed: 14.459414958953857 seconds
# USER 9750 COMPLETED----------------	Time Elapsed: 8.299342155456543 seconds
# USER 9800 COMPLETED----------------	Time Elapsed: 13.462171077728271 seconds
# USER 9850 COMPLETED----------------	Time Elapsed: 4.453451871871948 seconds
# USER 9900 COMPLETED----------------	Time Elapsed: 17.14331889152527 seconds
# USER 9950 COMPLETED----------------	Time Elapsed: 11.425677061080933 seconds
# USER 10000 COMPLETED----------------	Time Elapsed: 9.900445938110352 seconds
# USER 10050 COMPLETED----------------	Time Elapsed: 7.674113035202026 seconds
# USER 10100 COMPLETED----------------	Time Elapsed: 4.30167818069458 seconds
# USER 10150 COMPLETED----------------	Time Elapsed: 5.7967529296875 seconds
# USER 10200 COMPLETED----------------	Time Elapsed: 4.2522430419921875 seconds
# USER 10250 COMPLETED----------------	Time Elapsed: 9.365358114242554 seconds
# USER 10300 COMPLETED----------------	Time Elapsed: 6.369364976882935 seconds
# USER 10350 COMPLETED----------------	Time Elapsed: 4.200581073760986 seconds
# USER 10400 COMPLETED----------------	Time Elapsed: 11.837463140487671 seconds
# USER 10450 COMPLETED----------------	Time Elapsed: 6.995963096618652 seconds
# USER 10500 COMPLETED----------------	Time Elapsed: 9.93262505531311 seconds
# USER 10550 COMPLETED----------------	Time Elapsed: 8.220453262329102 seconds
# USER 10600 COMPLETED----------------	Time Elapsed: 15.480733871459961 seconds
# USER 10650 COMPLETED----------------	Time Elapsed: 14.267174005508423 seconds
# USER 10700 COMPLETED----------------	Time Elapsed: 9.471028089523315 seconds
# USER 10750 COMPLETED----------------	Time Elapsed: 20.48716902732849 seconds
# USER 10800 COMPLETED----------------	Time Elapsed: 29.263098001480103 seconds
# USER 10850 COMPLETED----------------	Time Elapsed: 8.98866319656372 seconds
# USER 10900 COMPLETED----------------	Time Elapsed: 5.821846961975098 seconds
# USER 10950 COMPLETED----------------	Time Elapsed: 5.884280204772949 seconds
# USER 11000 COMPLETED----------------	Time Elapsed: 22.831527948379517 seconds
# USER 11050 COMPLETED----------------	Time Elapsed: 7.407956838607788 seconds
# USER 11100 COMPLETED----------------	Time Elapsed: 11.62204909324646 seconds
# USER 11150 COMPLETED----------------	Time Elapsed: 5.738733768463135 seconds
# USER 11200 COMPLETED----------------	Time Elapsed: 12.34138798713684 seconds
# USER 11250 COMPLETED----------------	Time Elapsed: 4.650577783584595 seconds
# USER 11300 COMPLETED----------------	Time Elapsed: 5.752155065536499 seconds
# USER 11350 COMPLETED----------------	Time Elapsed: 21.867870807647705 seconds
# USER 11400 COMPLETED----------------	Time Elapsed: 4.83930516242981 seconds
# USER 11450 COMPLETED----------------	Time Elapsed: 5.225400924682617 seconds
# USER 11500 COMPLETED----------------	Time Elapsed: 4.056066989898682 seconds
# USER 11550 COMPLETED----------------	Time Elapsed: 6.074895143508911 seconds
# USER 11600 COMPLETED----------------	Time Elapsed: 12.25180697441101 seconds
# USER 11650 COMPLETED----------------	Time Elapsed: 3.528986930847168 seconds
# USER 11700 COMPLETED----------------	Time Elapsed: 7.18698525428772 seconds
# USER 11750 COMPLETED----------------	Time Elapsed: 7.120715141296387 seconds
# USER 11800 COMPLETED----------------	Time Elapsed: 5.743906736373901 seconds
# USER 11850 COMPLETED----------------	Time Elapsed: 7.4668238162994385 seconds
# USER 11900 COMPLETED----------------	Time Elapsed: 4.545034885406494 seconds
# USER 11950 COMPLETED----------------	Time Elapsed: 3.715808153152466 seconds
# USER 12000 COMPLETED----------------	Time Elapsed: 7.30267596244812 seconds
# USER 12050 COMPLETED----------------	Time Elapsed: 10.481252908706665 seconds
# USER 12100 COMPLETED----------------	Time Elapsed: 8.946765661239624 seconds
# USER 12150 COMPLETED----------------	Time Elapsed: 6.649703025817871 seconds
# USER 12200 COMPLETED----------------	Time Elapsed: 7.3208699226379395 seconds
# USER 12250 COMPLETED----------------	Time Elapsed: 14.975041151046753 seconds
# USER 12300 COMPLETED----------------	Time Elapsed: 20.021816968917847 seconds
# USER 12350 COMPLETED----------------	Time Elapsed: 3.828066110610962 seconds
# USER 12400 COMPLETED----------------	Time Elapsed: 8.226634979248047 seconds
# USER 12450 COMPLETED----------------	Time Elapsed: 17.533061027526855 seconds
# USER 12500 COMPLETED----------------	Time Elapsed: 12.497731924057007 seconds
# USER 12550 COMPLETED----------------	Time Elapsed: 5.88492488861084 seconds
# USER 12600 COMPLETED----------------	Time Elapsed: 12.955486297607422 seconds
# USER 12650 COMPLETED----------------	Time Elapsed: 8.757601022720337 seconds
# USER 12700 COMPLETED----------------	Time Elapsed: 6.652102947235107 seconds
# USER 12750 COMPLETED----------------	Time Elapsed: 13.304837942123413 seconds
# USER 12800 COMPLETED----------------	Time Elapsed: 18.29373598098755 seconds
# USER 12850 COMPLETED----------------	Time Elapsed: 4.164307117462158 seconds
# USER 12900 COMPLETED----------------	Time Elapsed: 3.9484469890594482 seconds
# USER 12950 COMPLETED----------------	Time Elapsed: 11.266660928726196 seconds
# USER 13000 COMPLETED----------------	Time Elapsed: 11.299255132675171 seconds
# USER 13050 COMPLETED----------------	Time Elapsed: 4.078687906265259 seconds
# USER 13100 COMPLETED----------------	Time Elapsed: 7.254985094070435 seconds
# USER 13150 COMPLETED----------------	Time Elapsed: 4.884613990783691 seconds
# USER 13200 COMPLETED----------------	Time Elapsed: 6.854784727096558 seconds
# USER 13250 COMPLETED----------------	Time Elapsed: 6.222962856292725 seconds
# USER 13300 COMPLETED----------------	Time Elapsed: 5.878568887710571 seconds
# USER 13350 COMPLETED----------------	Time Elapsed: 5.569493055343628 seconds
# USER 13400 COMPLETED----------------	Time Elapsed: 8.699589014053345 seconds
# USER 13450 COMPLETED----------------	Time Elapsed: 5.342402935028076 seconds
# USER 13500 COMPLETED----------------	Time Elapsed: 3.498405694961548 seconds
# USER 13550 COMPLETED----------------	Time Elapsed: 3.9887139797210693 seconds
# USER 13600 COMPLETED----------------	Time Elapsed: 8.09316611289978 seconds
# USER 13650 COMPLETED----------------	Time Elapsed: 12.691694021224976 seconds
# USER 13700 COMPLETED----------------	Time Elapsed: 2.7863450050354004 seconds
# USER 13750 COMPLETED----------------	Time Elapsed: 8.53709077835083 seconds
# USER 13800 COMPLETED----------------	Time Elapsed: 6.947063684463501 seconds
# USER 13850 COMPLETED----------------	Time Elapsed: 5.590960264205933 seconds
# USER 13900 COMPLETED----------------	Time Elapsed: 10.648578882217407 seconds
# USER 13950 COMPLETED----------------	Time Elapsed: 8.181794881820679 seconds
# USER 14000 COMPLETED----------------	Time Elapsed: 4.730377912521362 seconds
# USER 14050 COMPLETED----------------	Time Elapsed: 29.438604831695557 seconds
# USER 14100 COMPLETED----------------	Time Elapsed: 10.324428081512451 seconds
# USER 14150 COMPLETED----------------	Time Elapsed: 8.977160930633545 seconds
# USER 14200 COMPLETED----------------	Time Elapsed: 11.233583688735962 seconds
# USER 14250 COMPLETED----------------	Time Elapsed: 12.073238849639893 seconds
# USER 14300 COMPLETED----------------	Time Elapsed: 10.583651781082153 seconds
# USER 14350 COMPLETED----------------	Time Elapsed: 13.61140775680542 seconds
# USER 14400 COMPLETED----------------	Time Elapsed: 7.685077905654907 seconds
# USER 14450 COMPLETED----------------	Time Elapsed: 5.6018171310424805 seconds
# USER 14500 COMPLETED----------------	Time Elapsed: 5.420409679412842 seconds
# USER 14550 COMPLETED----------------	Time Elapsed: 8.8473379611969 seconds
# USER 14600 COMPLETED----------------	Time Elapsed: 6.495336055755615 seconds
# USER 14650 COMPLETED----------------	Time Elapsed: 7.8050761222839355 seconds
# USER 14700 COMPLETED----------------	Time Elapsed: 10.59457802772522 seconds
# USER 14750 COMPLETED----------------	Time Elapsed: 7.518965005874634 seconds
# USER 14800 COMPLETED----------------	Time Elapsed: 6.61127495765686 seconds
# USER 14850 COMPLETED----------------	Time Elapsed: 4.198743104934692 seconds
# USER 14900 COMPLETED----------------	Time Elapsed: 6.218410968780518 seconds
# USER 14950 COMPLETED----------------	Time Elapsed: 7.540489196777344 seconds
# USER 15000 COMPLETED----------------	Time Elapsed: 8.238522052764893 seconds
# USER 15050 COMPLETED----------------	Time Elapsed: 5.249470949172974 seconds
# USER 15100 COMPLETED----------------	Time Elapsed: 32.3989098072052 seconds
# USER 15150 COMPLETED----------------	Time Elapsed: 6.025301933288574 seconds
# USER 15200 COMPLETED----------------	Time Elapsed: 17.971054792404175 seconds
# USER 15250 COMPLETED----------------	Time Elapsed: 7.304017782211304 seconds
# USER 15300 COMPLETED----------------	Time Elapsed: 8.670793056488037 seconds
# USER 15350 COMPLETED----------------	Time Elapsed: 8.677088022232056 seconds
# USER 15400 COMPLETED----------------	Time Elapsed: 7.0667502880096436 seconds
# USER 15450 COMPLETED----------------	Time Elapsed: 5.884681940078735 seconds
# USER 15500 COMPLETED----------------	Time Elapsed: 7.046832084655762 seconds
# USER 15550 COMPLETED----------------	Time Elapsed: 4.038573980331421 seconds
# USER 15600 COMPLETED----------------	Time Elapsed: 3.123110294342041 seconds
# USER 15650 COMPLETED----------------	Time Elapsed: 9.246186256408691 seconds
# USER 15700 COMPLETED----------------	Time Elapsed: 5.53499698638916 seconds
# USER 15750 COMPLETED----------------	Time Elapsed: 6.226546287536621 seconds
# USER 15800 COMPLETED----------------	Time Elapsed: 6.680450916290283 seconds
# USER 15850 COMPLETED----------------	Time Elapsed: 9.54041314125061 seconds
# USER 15900 COMPLETED----------------	Time Elapsed: 13.436176300048828 seconds
# USER 15950 COMPLETED----------------	Time Elapsed: 5.5328049659729 seconds
# USER 16000 COMPLETED----------------	Time Elapsed: 11.530931949615479 seconds
# USER 16050 COMPLETED----------------	Time Elapsed: 12.057098865509033 seconds
# USER 16100 COMPLETED----------------	Time Elapsed: 5.403462886810303 seconds
# USER 16150 COMPLETED----------------	Time Elapsed: 5.435224771499634 seconds
# USER 16200 COMPLETED----------------	Time Elapsed: 4.5722010135650635 seconds
# USER 16250 COMPLETED----------------	Time Elapsed: 12.5604407787323 seconds
# USER 16300 COMPLETED----------------	Time Elapsed: 5.06344199180603 seconds
# USER 16350 COMPLETED----------------	Time Elapsed: 16.998301029205322 seconds
# USER 16400 COMPLETED----------------	Time Elapsed: 9.802855730056763 seconds
# USER 16450 COMPLETED----------------	Time Elapsed: 10.857509136199951 seconds
# USER 16500 COMPLETED----------------	Time Elapsed: 15.98063325881958 seconds
# USER 16550 COMPLETED----------------	Time Elapsed: 5.5781919956207275 seconds
# USER 16600 COMPLETED----------------	Time Elapsed: 5.82572603225708 seconds
# USER 16650 COMPLETED----------------	Time Elapsed: 9.92516803741455 seconds
# USER 16700 COMPLETED----------------	Time Elapsed: 11.030860900878906 seconds
# USER 16750 COMPLETED----------------	Time Elapsed: 11.042317152023315 seconds
# USER 16800 COMPLETED----------------	Time Elapsed: 4.406300783157349 seconds
# USER 16850 COMPLETED----------------	Time Elapsed: 4.586191892623901 seconds
# USER 16900 COMPLETED----------------	Time Elapsed: 7.508929967880249 seconds
# USER 16950 COMPLETED----------------	Time Elapsed: 7.997819900512695 seconds
# USER 17000 COMPLETED----------------	Time Elapsed: 4.206700801849365 seconds
# USER 17050 COMPLETED----------------	Time Elapsed: 8.75548791885376 seconds
# USER 17100 COMPLETED----------------	Time Elapsed: 10.708447217941284 seconds
# USER 17150 COMPLETED----------------	Time Elapsed: 8.661935806274414 seconds
# USER 17200 COMPLETED----------------	Time Elapsed: 7.431901931762695 seconds
# USER 17250 COMPLETED----------------	Time Elapsed: 4.626178979873657 seconds
# USER 17300 COMPLETED----------------	Time Elapsed: 5.563199043273926 seconds
# USER 17350 COMPLETED----------------	Time Elapsed: 33.88068890571594 seconds
# USER 17400 COMPLETED----------------	Time Elapsed: 25.95387601852417 seconds
# USER 17450 COMPLETED----------------	Time Elapsed: 5.563924074172974 seconds
# USER 17500 COMPLETED----------------	Time Elapsed: 4.5111918449401855 seconds
# USER 17550 COMPLETED----------------	Time Elapsed: 9.213029146194458 seconds
# USER 17600 COMPLETED----------------	Time Elapsed: 6.407754898071289 seconds
# USER 17650 COMPLETED----------------	Time Elapsed: 6.713583946228027 seconds
# USER 17700 COMPLETED----------------	Time Elapsed: 6.78417706489563 seconds
# USER 17750 COMPLETED----------------	Time Elapsed: 4.0874621868133545 seconds
# USER 17800 COMPLETED----------------	Time Elapsed: 6.5293707847595215 seconds
# USER 17850 COMPLETED----------------	Time Elapsed: 3.7734498977661133 seconds
# USER 17900 COMPLETED----------------	Time Elapsed: 12.2135591506958 seconds
# USER 17950 COMPLETED----------------	Time Elapsed: 14.608603239059448 seconds
# USER 18000 COMPLETED----------------	Time Elapsed: 7.653257131576538 seconds
# USER 18050 COMPLETED----------------	Time Elapsed: 5.426918983459473 seconds
# USER 18100 COMPLETED----------------	Time Elapsed: 3.2757198810577393 seconds
# USER 18150 COMPLETED----------------	Time Elapsed: 5.189294815063477 seconds
# USER 18200 COMPLETED----------------	Time Elapsed: 10.865848779678345 seconds
# USER 18250 COMPLETED----------------	Time Elapsed: 15.314222812652588 seconds
# USER 18300 COMPLETED----------------	Time Elapsed: 5.012205123901367 seconds
# USER 18350 COMPLETED----------------	Time Elapsed: 4.403184175491333 seconds
# USER 18400 COMPLETED----------------	Time Elapsed: 9.997549057006836 seconds
# USER 18450 COMPLETED----------------	Time Elapsed: 6.421619176864624 seconds
# USER 18500 COMPLETED----------------	Time Elapsed: 5.169464111328125 seconds
# USER 18550 COMPLETED----------------	Time Elapsed: 5.986142873764038 seconds
# USER 18600 COMPLETED----------------	Time Elapsed: 13.307316303253174 seconds
# USER 18650 COMPLETED----------------	Time Elapsed: 5.006155729293823 seconds
# USER 18700 COMPLETED----------------	Time Elapsed: 8.296635866165161 seconds
# USER 18750 COMPLETED----------------	Time Elapsed: 4.621798992156982 seconds
# USER 18800 COMPLETED----------------	Time Elapsed: 5.851471900939941 seconds
# USER 18850 COMPLETED----------------	Time Elapsed: 5.347292184829712 seconds
# USER 18900 COMPLETED----------------	Time Elapsed: 16.883980989456177 seconds
# USER 18950 COMPLETED----------------	Time Elapsed: 8.49911093711853 seconds
# USER 19000 COMPLETED----------------	Time Elapsed: 4.946783065795898 seconds
# USER 19050 COMPLETED----------------	Time Elapsed: 6.122447967529297 seconds
# USER 19100 COMPLETED----------------	Time Elapsed: 8.41946816444397 seconds
# USER 19150 COMPLETED----------------	Time Elapsed: 4.921700954437256 seconds
# USER 19200 COMPLETED----------------	Time Elapsed: 8.57336688041687 seconds
# USER 19250 COMPLETED----------------	Time Elapsed: 8.486233711242676 seconds
# USER 19300 COMPLETED----------------	Time Elapsed: 11.640803098678589 seconds
# USER 19350 COMPLETED----------------	Time Elapsed: 9.570598125457764 seconds
# USER 19400 COMPLETED----------------	Time Elapsed: 9.407624244689941 seconds
# USER 19450 COMPLETED----------------	Time Elapsed: 10.972578048706055 seconds
# USER 19500 COMPLETED----------------	Time Elapsed: 19.256110191345215 seconds
# USER 19550 COMPLETED----------------	Time Elapsed: 10.034964799880981 seconds
# USER 19600 COMPLETED----------------	Time Elapsed: 4.096112012863159 seconds
# USER 19650 COMPLETED----------------	Time Elapsed: 5.612814903259277 seconds
# USER 19700 COMPLETED----------------	Time Elapsed: 8.557271957397461 seconds
# USER 19750 COMPLETED----------------	Time Elapsed: 7.584311008453369 seconds
# USER 19800 COMPLETED----------------	Time Elapsed: 6.518040895462036 seconds
# USER 19850 COMPLETED----------------	Time Elapsed: 4.8351149559021 seconds
# USER 19900 COMPLETED----------------	Time Elapsed: 6.60424280166626 seconds
# USER 19950 COMPLETED----------------	Time Elapsed: 5.062626123428345 seconds
# USER 20000 COMPLETED----------------	Time Elapsed: 4.449563980102539 seconds
# USER 20050 COMPLETED----------------	Time Elapsed: 5.6068549156188965 seconds
# USER 20100 COMPLETED----------------	Time Elapsed: 7.179569721221924 seconds
# USER 20150 COMPLETED----------------	Time Elapsed: 6.767872095108032 seconds
# USER 20200 COMPLETED----------------	Time Elapsed: 7.085872173309326 seconds
# USER 20250 COMPLETED----------------	Time Elapsed: 6.339064121246338 seconds
# USER 20300 COMPLETED----------------	Time Elapsed: 11.111674070358276 seconds
# USER 20350 COMPLETED----------------	Time Elapsed: 5.017180919647217 seconds
# USER 20400 COMPLETED----------------	Time Elapsed: 6.855716705322266 seconds
# USER 20450 COMPLETED----------------	Time Elapsed: 7.171485900878906 seconds
# USER 20500 COMPLETED----------------	Time Elapsed: 6.3798699378967285 seconds
# USER 20550 COMPLETED----------------	Time Elapsed: 4.105540037155151 seconds
# USER 20600 COMPLETED----------------	Time Elapsed: 7.361901760101318 seconds
# USER 20650 COMPLETED----------------	Time Elapsed: 4.602901935577393 seconds
# USER 20700 COMPLETED----------------	Time Elapsed: 5.416039228439331 seconds
# USER 20750 COMPLETED----------------	Time Elapsed: 8.67215895652771 seconds
# USER 20800 COMPLETED----------------	Time Elapsed: 5.543231964111328 seconds
# USER 20850 COMPLETED----------------	Time Elapsed: 7.484800100326538 seconds
# USER 20900 COMPLETED----------------	Time Elapsed: 4.923938035964966 seconds
# USER 20950 COMPLETED----------------	Time Elapsed: 9.913242816925049 seconds
# USER 21000 COMPLETED----------------	Time Elapsed: 6.728945016860962 seconds
# USER 21050 COMPLETED----------------	Time Elapsed: 2.470557928085327 seconds
# USER 21100 COMPLETED----------------	Time Elapsed: 10.697425127029419 seconds
# USER 21150 COMPLETED----------------	Time Elapsed: 4.128345012664795 seconds
# USER 21200 COMPLETED----------------	Time Elapsed: 6.86223578453064 seconds
# USER 21250 COMPLETED----------------	Time Elapsed: 6.514333963394165 seconds
# USER 21300 COMPLETED----------------	Time Elapsed: 16.40952229499817 seconds
# USER 21350 COMPLETED----------------	Time Elapsed: 7.1196160316467285 seconds
# USER 21400 COMPLETED----------------	Time Elapsed: 14.064352989196777 seconds
# USER 21450 COMPLETED----------------	Time Elapsed: 7.751091957092285 seconds
# USER 21500 COMPLETED----------------	Time Elapsed: 5.816367149353027 seconds
# USER 21550 COMPLETED----------------	Time Elapsed: 7.237174987792969 seconds
# USER 21600 COMPLETED----------------	Time Elapsed: 6.030578851699829 seconds
# USER 21650 COMPLETED----------------	Time Elapsed: 7.298000812530518 seconds
# USER 21700 COMPLETED----------------	Time Elapsed: 8.136065006256104 seconds
# USER 21750 COMPLETED----------------	Time Elapsed: 3.799252986907959 seconds
# USER 21800 COMPLETED----------------	Time Elapsed: 14.574478149414062 seconds
# USER 21850 COMPLETED----------------	Time Elapsed: 23.13449192047119 seconds
# USER 21900 COMPLETED----------------	Time Elapsed: 9.326173067092896 seconds
# USER 21950 COMPLETED----------------	Time Elapsed: 13.934154987335205 seconds
# USER 22000 COMPLETED----------------	Time Elapsed: 5.366255044937134 seconds
# USER 22050 COMPLETED----------------	Time Elapsed: 8.528450012207031 seconds
# USER 22100 COMPLETED----------------	Time Elapsed: 6.0889410972595215 seconds
# USER 22150 COMPLETED----------------	Time Elapsed: 5.129254102706909 seconds
# USER 22200 COMPLETED----------------	Time Elapsed: 8.231075048446655 seconds
# USER 22250 COMPLETED----------------	Time Elapsed: 3.930523157119751 seconds
# USER 22300 COMPLETED----------------	Time Elapsed: 10.04268217086792 seconds
# USER 22350 COMPLETED----------------	Time Elapsed: 14.76778793334961 seconds
# USER 22400 COMPLETED----------------	Time Elapsed: 10.703404188156128 seconds
# USER 22450 COMPLETED----------------	Time Elapsed: 3.4559741020202637 seconds
# USER 22500 COMPLETED----------------	Time Elapsed: 11.114843845367432 seconds
# USER 22550 COMPLETED----------------	Time Elapsed: 3.521723747253418 seconds
# USER 22600 COMPLETED----------------	Time Elapsed: 15.482072114944458 seconds
# USER 22650 COMPLETED----------------	Time Elapsed: 84.40704369544983 seconds
# USER 22700 COMPLETED----------------	Time Elapsed: 13.24927282333374 seconds
# USER 22750 COMPLETED----------------	Time Elapsed: 5.262738943099976 seconds
# USER 22800 COMPLETED----------------	Time Elapsed: 10.774891138076782 seconds
# USER 22850 COMPLETED----------------	Time Elapsed: 5.226934909820557 seconds
# USER 22900 COMPLETED----------------	Time Elapsed: 13.488592147827148 seconds
# USER 22950 COMPLETED----------------	Time Elapsed: 4.358683109283447 seconds
# USER 23000 COMPLETED----------------	Time Elapsed: 14.335134983062744 seconds
# USER 23050 COMPLETED----------------	Time Elapsed: 11.915411949157715 seconds
# USER 23100 COMPLETED----------------	Time Elapsed: 8.781148195266724 seconds
# USER 23150 COMPLETED----------------	Time Elapsed: 16.749468326568604 seconds
# USER 23200 COMPLETED----------------	Time Elapsed: 13.04466199874878 seconds
# USER 23250 COMPLETED----------------	Time Elapsed: 3.055389881134033 seconds
# USER 23300 COMPLETED----------------	Time Elapsed: 14.069901943206787 seconds
# USER 23350 COMPLETED----------------	Time Elapsed: 9.050139904022217 seconds
# USER 23400 COMPLETED----------------	Time Elapsed: 5.1761109828948975 seconds
# USER 23450 COMPLETED----------------	Time Elapsed: 5.36902117729187 seconds
# USER 23500 COMPLETED----------------	Time Elapsed: 12.179605960845947 seconds
# USER 23550 COMPLETED----------------	Time Elapsed: 14.507241010665894 seconds
# USER 23600 COMPLETED----------------	Time Elapsed: 8.224519968032837 seconds
# USER 23650 COMPLETED----------------	Time Elapsed: 7.529002904891968 seconds
# USER 23700 COMPLETED----------------	Time Elapsed: 8.568289041519165 seconds
# USER 23750 COMPLETED----------------	Time Elapsed: 10.748223304748535 seconds
# USER 23800 COMPLETED----------------	Time Elapsed: 10.04518985748291 seconds
# USER 23850 COMPLETED----------------	Time Elapsed: 6.836325168609619 seconds
# USER 23900 COMPLETED----------------	Time Elapsed: 3.3190243244171143 seconds
# USER 23950 COMPLETED----------------	Time Elapsed: 6.035176992416382 seconds
# USER 24000 COMPLETED----------------	Time Elapsed: 9.999552965164185 seconds
# USER 24050 COMPLETED----------------	Time Elapsed: 6.2860329151153564 seconds
# USER 24100 COMPLETED----------------	Time Elapsed: 6.327550888061523 seconds
# USER 24150 COMPLETED----------------	Time Elapsed: 5.90865683555603 seconds
# USER 24200 COMPLETED----------------	Time Elapsed: 5.516373157501221 seconds
# USER 24250 COMPLETED----------------	Time Elapsed: 18.758599758148193 seconds
# USER 24300 COMPLETED----------------	Time Elapsed: 5.744296073913574 seconds
# USER 24350 COMPLETED----------------	Time Elapsed: 4.136311054229736 seconds
# USER 24400 COMPLETED----------------	Time Elapsed: 5.210919141769409 seconds
# USER 24450 COMPLETED----------------	Time Elapsed: 5.272018909454346 seconds
# USER 24500 COMPLETED----------------	Time Elapsed: 8.759529113769531 seconds
# USER 24550 COMPLETED----------------	Time Elapsed: 5.508259057998657 seconds
# USER 24600 COMPLETED----------------	Time Elapsed: 11.95847487449646 seconds
# USER 24650 COMPLETED----------------	Time Elapsed: 6.375140905380249 seconds
# USER 24700 COMPLETED----------------	Time Elapsed: 4.555027008056641 seconds
# USER 24750 COMPLETED----------------	Time Elapsed: 10.758257865905762 seconds
# USER 24800 COMPLETED----------------	Time Elapsed: 6.312222003936768 seconds
# USER 24850 COMPLETED----------------	Time Elapsed: 11.026234865188599 seconds
# USER 24900 COMPLETED----------------	Time Elapsed: 11.455402135848999 seconds
# USER 24950 COMPLETED----------------	Time Elapsed: 7.823637008666992 seconds
# USER 25000 COMPLETED----------------	Time Elapsed: 3.096325159072876 seconds
# USER 25050 COMPLETED----------------	Time Elapsed: 5.567080974578857 seconds
# USER 25100 COMPLETED----------------	Time Elapsed: 10.087743282318115 seconds
# USER 25150 COMPLETED----------------	Time Elapsed: 7.673828840255737 seconds
# USER 25200 COMPLETED----------------	Time Elapsed: 7.703877925872803 seconds
# USER 25250 COMPLETED----------------	Time Elapsed: 3.660184860229492 seconds
# USER 25300 COMPLETED----------------	Time Elapsed: 6.279484987258911 seconds
# USER 25350 COMPLETED----------------	Time Elapsed: 4.2689948081970215 seconds
# USER 25400 COMPLETED----------------	Time Elapsed: 4.039918899536133 seconds
# USER 25450 COMPLETED----------------	Time Elapsed: 5.972123861312866 seconds
# USER 25500 COMPLETED----------------	Time Elapsed: 5.175458192825317 seconds
# USER 25550 COMPLETED----------------	Time Elapsed: 4.4833667278289795 seconds
# USER 25600 COMPLETED----------------	Time Elapsed: 13.894110918045044 seconds
# USER 25650 COMPLETED----------------	Time Elapsed: 6.553744077682495 seconds
# USER 25700 COMPLETED----------------	Time Elapsed: 7.857221841812134 seconds
# USER 25750 COMPLETED----------------	Time Elapsed: 5.993411064147949 seconds
# USER 25800 COMPLETED----------------	Time Elapsed: 19.913300037384033 seconds
# USER 25850 COMPLETED----------------	Time Elapsed: 5.459788084030151 seconds
# USER 25900 COMPLETED----------------	Time Elapsed: 6.6867289543151855 seconds
# USER 25950 COMPLETED----------------	Time Elapsed: 5.484622001647949 seconds
# USER 26000 COMPLETED----------------	Time Elapsed: 5.340106964111328 seconds
# USER 26050 COMPLETED----------------	Time Elapsed: 6.1763341426849365 seconds
# USER 26100 COMPLETED----------------	Time Elapsed: 8.191565990447998 seconds
# USER 26150 COMPLETED----------------	Time Elapsed: 12.992011070251465 seconds
# USER 26200 COMPLETED----------------	Time Elapsed: 5.155917644500732 seconds
# USER 26250 COMPLETED----------------	Time Elapsed: 23.49371862411499 seconds
# USER 26300 COMPLETED----------------	Time Elapsed: 7.116492033004761 seconds
# USER 26350 COMPLETED----------------	Time Elapsed: 5.443289041519165 seconds
# USER 26400 COMPLETED----------------	Time Elapsed: 8.381233930587769 seconds
# USER 26450 COMPLETED----------------	Time Elapsed: 16.43557596206665 seconds
# USER 26500 COMPLETED----------------	Time Elapsed: 4.38769006729126 seconds
# USER 26550 COMPLETED----------------	Time Elapsed: 5.051287651062012 seconds
# USER 26600 COMPLETED----------------	Time Elapsed: 5.840002059936523 seconds
# USER 26650 COMPLETED----------------	Time Elapsed: 14.083555221557617 seconds
# USER 26700 COMPLETED----------------	Time Elapsed: 7.851078748703003 seconds
# USER 26750 COMPLETED----------------	Time Elapsed: 8.926194906234741 seconds
# USER 26800 COMPLETED----------------	Time Elapsed: 5.078305006027222 seconds
# USER 26850 COMPLETED----------------	Time Elapsed: 8.539357900619507 seconds
# USER 26900 COMPLETED----------------	Time Elapsed: 3.874729871749878 seconds
# USER 26950 COMPLETED----------------	Time Elapsed: 5.259597063064575 seconds
# USER 27000 COMPLETED----------------	Time Elapsed: 10.16409182548523 seconds
# USER 27050 COMPLETED----------------	Time Elapsed: 9.8067626953125 seconds
# USER 27100 COMPLETED----------------	Time Elapsed: 33.726011991500854 seconds
# USER 27150 COMPLETED----------------	Time Elapsed: 5.2505998611450195 seconds
# USER 27200 COMPLETED----------------	Time Elapsed: 5.831594944000244 seconds
# USER 27250 COMPLETED----------------	Time Elapsed: 7.8350160121917725 seconds
# USER 27300 COMPLETED----------------	Time Elapsed: 4.17686915397644 seconds
# USER 27350 COMPLETED----------------	Time Elapsed: 5.659124851226807 seconds
# USER 27400 COMPLETED----------------	Time Elapsed: 13.289446115493774 seconds
# USER 27450 COMPLETED----------------	Time Elapsed: 6.76360011100769 seconds
# USER 27500 COMPLETED----------------	Time Elapsed: 24.515632152557373 seconds
# USER 27550 COMPLETED----------------	Time Elapsed: 4.669379949569702 seconds
# USER 27600 COMPLETED----------------	Time Elapsed: 5.651911020278931 seconds
# USER 27650 COMPLETED----------------	Time Elapsed: 10.158138275146484 seconds
# USER 27700 COMPLETED----------------	Time Elapsed: 13.266856908798218 seconds
# USER 27750 COMPLETED----------------	Time Elapsed: 3.479641914367676 seconds
# USER 27800 COMPLETED----------------	Time Elapsed: 3.409921646118164 seconds
# USER 27850 COMPLETED----------------	Time Elapsed: 6.138682842254639 seconds
# USER 27900 COMPLETED----------------	Time Elapsed: 17.63886284828186 seconds
# USER 27950 COMPLETED----------------	Time Elapsed: 6.09456992149353 seconds
# USER 28000 COMPLETED----------------	Time Elapsed: 6.044037818908691 seconds
# USER 28050 COMPLETED----------------	Time Elapsed: 10.073509931564331 seconds
# USER 28100 COMPLETED----------------	Time Elapsed: 9.284539937973022 seconds
# USER 28150 COMPLETED----------------	Time Elapsed: 5.215367794036865 seconds
# USER 28200 COMPLETED----------------	Time Elapsed: 6.375227689743042 seconds
# USER 28250 COMPLETED----------------	Time Elapsed: 15.916780710220337 seconds
# USER 28300 COMPLETED----------------	Time Elapsed: 8.550108909606934 seconds
# USER 28350 COMPLETED----------------	Time Elapsed: 5.269046068191528 seconds
# USER 28400 COMPLETED----------------	Time Elapsed: 8.862813949584961 seconds
# USER 28450 COMPLETED----------------	Time Elapsed: 9.589831829071045 seconds
# USER 28500 COMPLETED----------------	Time Elapsed: 7.588828802108765 seconds
# USER 28550 COMPLETED----------------	Time Elapsed: 12.167848110198975 seconds
# USER 28600 COMPLETED----------------	Time Elapsed: 6.9388957023620605 seconds
# USER 28650 COMPLETED----------------	Time Elapsed: 18.666499853134155 seconds
# USER 28700 COMPLETED----------------	Time Elapsed: 3.43212890625 seconds
# USER 28750 COMPLETED----------------	Time Elapsed: 3.9353737831115723 seconds
# USER 28800 COMPLETED----------------	Time Elapsed: 7.150483846664429 seconds
# USER 28850 COMPLETED----------------	Time Elapsed: 4.424335241317749 seconds
# USER 28900 COMPLETED----------------	Time Elapsed: 4.368653059005737 seconds
# USER 28950 COMPLETED----------------	Time Elapsed: 30.07220196723938 seconds
# USER 29000 COMPLETED----------------	Time Elapsed: 7.873818874359131 seconds
# USER 29050 COMPLETED----------------	Time Elapsed: 3.9337317943573 seconds
# USER 29100 COMPLETED----------------	Time Elapsed: 13.067184925079346 seconds
# USER 29150 COMPLETED----------------	Time Elapsed: 9.052929162979126 seconds
# USER 29200 COMPLETED----------------	Time Elapsed: 4.6767048835754395 seconds
# USER 29250 COMPLETED----------------	Time Elapsed: 7.247231960296631 seconds
# USER 29300 COMPLETED----------------	Time Elapsed: 15.523151159286499 seconds
# USER 29350 COMPLETED----------------	Time Elapsed: 8.06971287727356 seconds
# USER 29400 COMPLETED----------------	Time Elapsed: 9.797266960144043 seconds
# USER 29450 COMPLETED----------------	Time Elapsed: 8.91427206993103 seconds
# USER 29500 COMPLETED----------------	Time Elapsed: 8.401063203811646 seconds
# USER 29550 COMPLETED----------------	Time Elapsed: 6.069085121154785 seconds
# USER 29600 COMPLETED----------------	Time Elapsed: 4.318159818649292 seconds
# USER 29650 COMPLETED----------------	Time Elapsed: 7.09513783454895 seconds
# USER 29700 COMPLETED----------------	Time Elapsed: 4.529814958572388 seconds
# USER 29750 COMPLETED----------------	Time Elapsed: 11.503216981887817 seconds
# USER 29800 COMPLETED----------------	Time Elapsed: 3.834928035736084 seconds
# USER 29850 COMPLETED----------------	Time Elapsed: 8.146509885787964 seconds
# USER 29900 COMPLETED----------------	Time Elapsed: 7.635240316390991 seconds
# USER 29950 COMPLETED----------------	Time Elapsed: 6.268383026123047 seconds
# USER 30000 COMPLETED----------------	Time Elapsed: 28.92482900619507 seconds
# USER 30050 COMPLETED----------------	Time Elapsed: 6.3392181396484375 seconds
# USER 30100 COMPLETED----------------	Time Elapsed: 6.747442960739136 seconds
# USER 30150 COMPLETED----------------	Time Elapsed: 7.87297797203064 seconds
# USER 30200 COMPLETED----------------	Time Elapsed: 4.73472785949707 seconds
# USER 30250 COMPLETED----------------	Time Elapsed: 5.5543212890625 seconds
# USER 30300 COMPLETED----------------	Time Elapsed: 4.885686874389648 seconds
# USER 30350 COMPLETED----------------	Time Elapsed: 6.153232097625732 seconds
# USER 30400 COMPLETED----------------	Time Elapsed: 5.196293115615845 seconds
# USER 30450 COMPLETED----------------	Time Elapsed: 20.502985954284668 seconds
# USER 30500 COMPLETED----------------	Time Elapsed: 9.544179916381836 seconds
# USER 30550 COMPLETED----------------	Time Elapsed: 9.501899003982544 seconds
# USER 30600 COMPLETED----------------	Time Elapsed: 4.7293431758880615 seconds
# USER 30650 COMPLETED----------------	Time Elapsed: 5.60391092300415 seconds
# USER 30700 COMPLETED----------------	Time Elapsed: 8.521728038787842 seconds
# USER 30750 COMPLETED----------------	Time Elapsed: 6.840795040130615 seconds
# USER 30800 COMPLETED----------------	Time Elapsed: 4.114326000213623 seconds
# USER 30850 COMPLETED----------------	Time Elapsed: 8.056884050369263 seconds
# USER 30900 COMPLETED----------------	Time Elapsed: 8.554224967956543 seconds
# USER 30950 COMPLETED----------------	Time Elapsed: 6.563591241836548 seconds
# USER 31000 COMPLETED----------------	Time Elapsed: 7.107544898986816 seconds
# USER 31050 COMPLETED----------------	Time Elapsed: 4.14126992225647 seconds
# USER 31100 COMPLETED----------------	Time Elapsed: 10.119621992111206 seconds
# USER 31150 COMPLETED----------------	Time Elapsed: 7.633004665374756 seconds
# ...
# USER 88350 COMPLETED----------------	Time Elapsed: 8.712818384170532 seconds
# USER 88400 COMPLETED----------------	Time Elapsed: 18.95558190345764 seconds
# USER 88450 COMPLETED----------------	Time Elapsed: 7.117835998535156 seconds
# USER 88500 COMPLETED----------------	Time Elapsed: 13.644256114959717 seconds
# USER 88550 COMPLETED----------------	Time Elapsed: 6.107424020767212 seconds
# USER 88600 COMPLETED----------------	Time Elapsed: 6.0640459060668945 seconds
# USER 88650 COMPLETED----------------	Time Elapsed: 5.444918632507324 seconds
# USER 88700 COMPLETED----------------	Time Elapsed: 13.580584287643433 seconds
# USER 88750 COMPLETED----------------	Time Elapsed: 7.5723419189453125 seconds
# USER 88800 COMPLETED----------------	Time Elapsed: 5.088613748550415 seconds
# USER 88850 COMPLETED----------------	Time Elapsed: 7.046310901641846 seconds
# USER 88900 COMPLETED----------------	Time Elapsed: 8.341410875320435 seconds
# USER 88950 COMPLETED----------------	Time Elapsed: 11.017619132995605 seconds
# USER 89000 COMPLETED----------------	Time Elapsed: 7.516226053237915 seconds
# USER 89050 COMPLETED----------------	Time Elapsed: 9.354207038879395 seconds
# USER 89100 COMPLETED----------------	Time Elapsed: 4.717778205871582 seconds
# USER 89150 COMPLETED----------------	Time Elapsed: 11.86788034439087 seconds
# USER 89200 COMPLETED----------------	Time Elapsed: 3.44793701171875 seconds
# USER 89250 COMPLETED----------------	Time Elapsed: 11.795756101608276 seconds
# USER 89300 COMPLETED----------------	Time Elapsed: 8.427705764770508 seconds
# USER 89350 COMPLETED----------------	Time Elapsed: 3.721268892288208 seconds
# USER 89400 COMPLETED----------------	Time Elapsed: 4.181969165802002 seconds
# USER 89450 COMPLETED----------------	Time Elapsed: 16.862031936645508 seconds
# USER 89500 COMPLETED----------------	Time Elapsed: 9.909204959869385 seconds
# USER 89550 COMPLETED----------------	Time Elapsed: 13.612308025360107 seconds
# USER 89600 COMPLETED----------------	Time Elapsed: 4.002213954925537 seconds
# USER 89650 COMPLETED----------------	Time Elapsed: 22.832552909851074 seconds
# USER 89700 COMPLETED----------------	Time Elapsed: 8.71912407875061 seconds
# USER 89750 COMPLETED----------------	Time Elapsed: 5.962166786193848 seconds
# USER 89800 COMPLETED----------------	Time Elapsed: 15.71498703956604 seconds
# USER 89850 COMPLETED----------------	Time Elapsed: 17.62049627304077 seconds
# USER 89900 COMPLETED----------------	Time Elapsed: 5.771490097045898 seconds
# USER 89950 COMPLETED----------------	Time Elapsed: 5.431328773498535 seconds
# USER 90000 COMPLETED----------------	Time Elapsed: 9.263962984085083 seconds
# USER 90050 COMPLETED----------------	Time Elapsed: 4.371716022491455 seconds
# USER 90100 COMPLETED----------------	Time Elapsed: 9.813781023025513 seconds
# USER 90150 COMPLETED----------------	Time Elapsed: 4.183053970336914 seconds
# USER 90200 COMPLETED----------------	Time Elapsed: 4.857216119766235 seconds
# USER 90250 COMPLETED----------------	Time Elapsed: 5.813996076583862 seconds
# USER 90300 COMPLETED----------------	Time Elapsed: 6.882017135620117 seconds
# USER 90350 COMPLETED----------------	Time Elapsed: 4.710468053817749 seconds
# USER 90400 COMPLETED----------------	Time Elapsed: 5.8653950691223145 seconds
# USER 90450 COMPLETED----------------	Time Elapsed: 26.59155011177063 seconds
# USER 90500 COMPLETED----------------	Time Elapsed: 21.757760047912598 seconds
# USER 90550 COMPLETED----------------	Time Elapsed: 5.070021867752075 seconds
# USER 90600 COMPLETED----------------	Time Elapsed: 5.222893953323364 seconds
# USER 90650 COMPLETED----------------	Time Elapsed: 7.378305912017822 seconds
# USER 90700 COMPLETED----------------	Time Elapsed: 5.513719797134399 seconds
# USER 90750 COMPLETED----------------	Time Elapsed: 5.1267409324646 seconds
# USER 90800 COMPLETED----------------	Time Elapsed: 4.390791177749634 seconds
# USER 90850 COMPLETED----------------	Time Elapsed: 4.714078187942505 seconds
# USER 90900 COMPLETED----------------	Time Elapsed: 6.1265130043029785 seconds
# USER 90950 COMPLETED----------------	Time Elapsed: 9.232528924942017 seconds
# USER 91000 COMPLETED----------------	Time Elapsed: 5.8647449016571045 seconds
# USER 91050 COMPLETED----------------	Time Elapsed: 32.13045310974121 seconds
# USER 91100 COMPLETED----------------	Time Elapsed: 7.169885873794556 seconds
# USER 91150 COMPLETED----------------	Time Elapsed: 4.694293975830078 seconds
# USER 91200 COMPLETED----------------	Time Elapsed: 5.713465690612793 seconds
# USER 91250 COMPLETED----------------	Time Elapsed: 9.83250617980957 seconds
# USER 91300 COMPLETED----------------	Time Elapsed: 10.360830068588257 seconds
# USER 91350 COMPLETED----------------	Time Elapsed: 6.540396213531494 seconds
# USER 91400 COMPLETED----------------	Time Elapsed: 6.711772918701172 seconds
# USER 91450 COMPLETED----------------	Time Elapsed: 10.811084032058716 seconds
# USER 91500 COMPLETED----------------	Time Elapsed: 4.454782009124756 seconds
# USER 91550 COMPLETED----------------	Time Elapsed: 9.287321090698242 seconds
# USER 91600 COMPLETED----------------	Time Elapsed: 12.610666990280151 seconds
# USER 91650 COMPLETED----------------	Time Elapsed: 10.18675684928894 seconds
# USER 91700 COMPLETED----------------	Time Elapsed: 3.1512999534606934 seconds
# USER 91750 COMPLETED----------------	Time Elapsed: 4.9449381828308105 seconds
# USER 91800 COMPLETED----------------	Time Elapsed: 7.91925311088562 seconds
# USER 91850 COMPLETED----------------	Time Elapsed: 3.962733030319214 seconds
# USER 91900 COMPLETED----------------	Time Elapsed: 3.8890228271484375 seconds
# USER 91950 COMPLETED----------------	Time Elapsed: 9.250375032424927 seconds
# USER 92000 COMPLETED----------------	Time Elapsed: 3.8673689365386963 seconds
# USER 92050 COMPLETED----------------	Time Elapsed: 5.793565988540649 seconds
# USER 92100 COMPLETED----------------	Time Elapsed: 6.305329084396362 seconds
# USER 92150 COMPLETED----------------	Time Elapsed: 6.591408729553223 seconds
# USER 92200 COMPLETED----------------	Time Elapsed: 5.956531286239624 seconds
# USER 92250 COMPLETED----------------	Time Elapsed: 3.2354679107666016 seconds
# USER 92300 COMPLETED----------------	Time Elapsed: 3.476935863494873 seconds
# USER 92350 COMPLETED----------------	Time Elapsed: 7.26535701751709 seconds
# USER 92400 COMPLETED----------------	Time Elapsed: 5.099825859069824 seconds
# USER 92450 COMPLETED----------------	Time Elapsed: 6.74926495552063 seconds
# USER 92500 COMPLETED----------------	Time Elapsed: 11.418539047241211 seconds
# USER 92550 COMPLETED----------------	Time Elapsed: 13.801197052001953 seconds
# USER 92600 COMPLETED----------------	Time Elapsed: 4.995006799697876 seconds
# USER 92650 COMPLETED----------------	Time Elapsed: 13.881319046020508 seconds
# USER 92700 COMPLETED----------------	Time Elapsed: 10.58909821510315 seconds
# USER 92750 COMPLETED----------------	Time Elapsed: 3.527678966522217 seconds
# USER 92800 COMPLETED----------------	Time Elapsed: 8.296679973602295 seconds
# USER 92850 COMPLETED----------------	Time Elapsed: 7.726655006408691 seconds
# USER 92900 COMPLETED----------------	Time Elapsed: 4.947358131408691 seconds
# USER 92950 COMPLETED----------------	Time Elapsed: 7.525432109832764 seconds
# USER 93000 COMPLETED----------------	Time Elapsed: 6.577733993530273 seconds
# USER 93050 COMPLETED----------------	Time Elapsed: 9.12549614906311 seconds
# USER 93100 COMPLETED----------------	Time Elapsed: 9.534928321838379 seconds
# USER 93150 COMPLETED----------------	Time Elapsed: 6.387253999710083 seconds
# USER 93200 COMPLETED----------------	Time Elapsed: 35.99375009536743 seconds
# USER 93250 COMPLETED----------------	Time Elapsed: 11.256438970565796 seconds
# USER 93300 COMPLETED----------------	Time Elapsed: 24.327900886535645 seconds
# USER 93350 COMPLETED----------------	Time Elapsed: 6.291962146759033 seconds
# USER 93400 COMPLETED----------------	Time Elapsed: 5.188667058944702 seconds
# USER 93450 COMPLETED----------------	Time Elapsed: 18.62777280807495 seconds
# USER 93500 COMPLETED----------------	Time Elapsed: 6.879081964492798 seconds
# USER 93550 COMPLETED----------------	Time Elapsed: 33.52854895591736 seconds
# USER 93600 COMPLETED----------------	Time Elapsed: 2.981656074523926 seconds
# USER 93650 COMPLETED----------------	Time Elapsed: 11.921850204467773 seconds
# USER 93700 COMPLETED----------------	Time Elapsed: 8.207025051116943 seconds
# USER 93750 COMPLETED----------------	Time Elapsed: 4.455487966537476 seconds
# USER 93800 COMPLETED----------------	Time Elapsed: 5.9137561321258545 seconds
# USER 93850 COMPLETED----------------	Time Elapsed: 4.573811054229736 seconds
# USER 93900 COMPLETED----------------	Time Elapsed: 4.7282490730285645 seconds
# USER 93950 COMPLETED----------------	Time Elapsed: 6.675673961639404 seconds
# USER 94000 COMPLETED----------------	Time Elapsed: 14.928153038024902 seconds
# USER 94050 COMPLETED----------------	Time Elapsed: 3.9732279777526855 seconds
# USER 94100 COMPLETED----------------	Time Elapsed: 9.474213123321533 seconds
# USER 94150 COMPLETED----------------	Time Elapsed: 6.944506883621216 seconds
# USER 94200 COMPLETED----------------	Time Elapsed: 5.488396167755127 seconds
# USER 94250 COMPLETED----------------	Time Elapsed: 8.465071678161621 seconds
# USER 94300 COMPLETED----------------	Time Elapsed: 7.258122682571411 seconds
# USER 94350 COMPLETED----------------	Time Elapsed: 18.97777509689331 seconds
# USER 94400 COMPLETED----------------	Time Elapsed: 5.395875692367554 seconds
# USER 94450 COMPLETED----------------	Time Elapsed: 6.772075176239014 seconds
# USER 94500 COMPLETED----------------	Time Elapsed: 5.127472877502441 seconds
# USER 94550 COMPLETED----------------	Time Elapsed: 2.910752773284912 seconds
# USER 94600 COMPLETED----------------	Time Elapsed: 18.454209089279175 seconds
# USER 94650 COMPLETED----------------	Time Elapsed: 8.717194080352783 seconds
# USER 94700 COMPLETED----------------	Time Elapsed: 8.271146059036255 seconds
# USER 94750 COMPLETED----------------	Time Elapsed: 5.6475160121917725 seconds
# USER 94800 COMPLETED----------------	Time Elapsed: 39.00314283370972 seconds
# USER 94850 COMPLETED----------------	Time Elapsed: 12.031527996063232 seconds
# USER 94900 COMPLETED----------------	Time Elapsed: 6.599456071853638 seconds
# USER 94950 COMPLETED----------------	Time Elapsed: 3.480031967163086 seconds
# USER 95000 COMPLETED----------------	Time Elapsed: 8.64988088607788 seconds
# USER 95050 COMPLETED----------------	Time Elapsed: 8.575117826461792 seconds
# USER 95100 COMPLETED----------------	Time Elapsed: 3.886245012283325 seconds
# USER 95150 COMPLETED----------------	Time Elapsed: 16.42611289024353 seconds
# USER 95200 COMPLETED----------------	Time Elapsed: 7.608678102493286 seconds
# USER 95250 COMPLETED----------------	Time Elapsed: 6.266532897949219 seconds
# USER 95300 COMPLETED----------------	Time Elapsed: 12.727816820144653 seconds
# USER 95350 COMPLETED----------------	Time Elapsed: 12.327489852905273 seconds
# USER 95400 COMPLETED----------------	Time Elapsed: 5.417402744293213 seconds
# USER 95450 COMPLETED----------------	Time Elapsed: 11.308638334274292 seconds
# USER 95500 COMPLETED----------------	Time Elapsed: 4.979013919830322 seconds
# USER 95550 COMPLETED----------------	Time Elapsed: 7.208217144012451 seconds
# USER 95600 COMPLETED----------------	Time Elapsed: 5.491039991378784 seconds
# USER 95650 COMPLETED----------------	Time Elapsed: 4.035370111465454 seconds
# USER 95700 COMPLETED----------------	Time Elapsed: 8.210839033126831 seconds
# USER 95750 COMPLETED----------------	Time Elapsed: 13.815598011016846 seconds
# USER 95800 COMPLETED----------------	Time Elapsed: 13.51776933670044 seconds
# USER 95850 COMPLETED----------------	Time Elapsed: 6.453256130218506 seconds
# USER 95900 COMPLETED----------------	Time Elapsed: 6.214946031570435 seconds
# USER 95950 COMPLETED----------------	Time Elapsed: 4.40684175491333 seconds
# USER 96000 COMPLETED----------------	Time Elapsed: 7.467023849487305 seconds
# USER 96050 COMPLETED----------------	Time Elapsed: 8.431433200836182 seconds
# USER 96100 COMPLETED----------------	Time Elapsed: 13.647771835327148 seconds
# USER 96150 COMPLETED----------------	Time Elapsed: 6.455413103103638 seconds
# USER 96200 COMPLETED----------------	Time Elapsed: 3.5430052280426025 seconds
# USER 96250 COMPLETED----------------	Time Elapsed: 7.903961896896362 seconds
# USER 96300 COMPLETED----------------	Time Elapsed: 9.519840955734253 seconds
# USER 96350 COMPLETED----------------	Time Elapsed: 8.653976917266846 seconds
# USER 96400 COMPLETED----------------	Time Elapsed: 7.706801891326904 seconds
# USER 96450 COMPLETED----------------	Time Elapsed: 7.365599870681763 seconds
# USER 96500 COMPLETED----------------	Time Elapsed: 4.887778997421265 seconds
# USER 96550 COMPLETED----------------	Time Elapsed: 10.307008028030396 seconds
# USER 96600 COMPLETED----------------	Time Elapsed: 7.368854999542236 seconds
# USER 96650 COMPLETED----------------	Time Elapsed: 10.5730299949646 seconds
# USER 96700 COMPLETED----------------	Time Elapsed: 8.551643133163452 seconds
# USER 96750 COMPLETED----------------	Time Elapsed: 4.661375045776367 seconds
# USER 96800 COMPLETED----------------	Time Elapsed: 6.172899007797241 seconds
# USER 96850 COMPLETED----------------	Time Elapsed: 10.550962209701538 seconds
# USER 96900 COMPLETED----------------	Time Elapsed: 6.171365022659302 seconds
# USER 96950 COMPLETED----------------	Time Elapsed: 6.684057950973511 seconds
# USER 97000 COMPLETED----------------	Time Elapsed: 5.45468282699585 seconds
# USER 97050 COMPLETED----------------	Time Elapsed: 3.9148271083831787 seconds
# USER 97100 COMPLETED----------------	Time Elapsed: 7.135082960128784 seconds
# USER 97150 COMPLETED----------------	Time Elapsed: 5.0414369106292725 seconds
# USER 97200 COMPLETED----------------	Time Elapsed: 3.932234048843384 seconds
# USER 97250 COMPLETED----------------	Time Elapsed: 4.298328161239624 seconds
# USER 97300 COMPLETED----------------	Time Elapsed: 4.817958831787109 seconds
# USER 97350 COMPLETED----------------	Time Elapsed: 8.352895975112915 seconds
# USER 97400 COMPLETED----------------	Time Elapsed: 23.899656057357788 seconds
# USER 97450 COMPLETED----------------	Time Elapsed: 10.850831031799316 seconds
# USER 97500 COMPLETED----------------	Time Elapsed: 18.66027522087097 seconds
# USER 97550 COMPLETED----------------	Time Elapsed: 4.725459098815918 seconds
# USER 97600 COMPLETED----------------	Time Elapsed: 5.661540985107422 seconds
# USER 97650 COMPLETED----------------	Time Elapsed: 8.251237869262695 seconds
# USER 97700 COMPLETED----------------	Time Elapsed: 10.710602283477783 seconds
# USER 97750 COMPLETED----------------	Time Elapsed: 22.377089023590088 seconds
# USER 97800 COMPLETED----------------	Time Elapsed: 7.426181077957153 seconds
# USER 97850 COMPLETED----------------	Time Elapsed: 6.780454874038696 seconds
# USER 97900 COMPLETED----------------	Time Elapsed: 4.257781982421875 seconds
# USER 97950 COMPLETED----------------	Time Elapsed: 7.570835113525391 seconds
# USER 98000 COMPLETED----------------	Time Elapsed: 6.786718845367432 seconds
# USER 98050 COMPLETED----------------	Time Elapsed: 5.440855979919434 seconds
# USER 98100 COMPLETED----------------	Time Elapsed: 7.284211158752441 seconds
# USER 98150 COMPLETED----------------	Time Elapsed: 7.244558811187744 seconds
# USER 98200 COMPLETED----------------	Time Elapsed: 25.563385009765625 seconds
# USER 98250 COMPLETED----------------	Time Elapsed: 7.120337963104248 seconds
# USER 98300 COMPLETED----------------	Time Elapsed: 8.06688928604126 seconds
# USER 98350 COMPLETED----------------	Time Elapsed: 6.092140197753906 seconds
# USER 98400 COMPLETED----------------	Time Elapsed: 9.457422971725464 seconds
# USER 98450 COMPLETED----------------	Time Elapsed: 5.181643962860107 seconds
# USER 98500 COMPLETED----------------	Time Elapsed: 11.4518461227417 seconds
# USER 98550 COMPLETED----------------	Time Elapsed: 19.549746990203857 seconds
# USER 98600 COMPLETED----------------	Time Elapsed: 7.650840997695923 seconds
# USER 98650 COMPLETED----------------	Time Elapsed: 17.628029108047485 seconds

# %%
# to get the skill parameters
f = open('skill_params.json')
params = json.load(f)

# %% [markdown]
# ### Looking at parameter distributions

# %%
df_params = pd.DataFrame(params).T
df_params.drop('-1', inplace=True)
df_params
# Out:
#        p_init  p_transit   p_guess    p_slip
# 131  0.721816   0.266157  0.283920  0.173870
# 93   0.770456   0.510148  0.149957  0.089715
# 81   0.549010   0.148939  0.358141  0.262111
# 10   0.327621   0.255193  0.227717  0.224273
# 94   0.377834   0.358519  0.122535  0.153673
# ..        ...        ...       ...       ...
# 139  0.631673   0.402746  0.257155  0.125458
# 11   0.258517   0.241626  0.223282  0.216444
# 59   0.443121   0.360506  0.235307  0.165463
# 86   0.572785   0.616438  0.008499  0.005906
# 186  0.337538   0.383242  0.183690  0.155731
#
# [188 rows x 4 columns]

# %%
# viz param dist
plt.figure(figsize=(10,6))
sns.kdeplot(data=df_params, fill=True, palette='viridis')
plt.xlabel('Probability')
plt.title('Parameter Distributions')
plt.show()

# %%
# checking for model degeneracy
np.where((df_params['p_guess'] >= 0.5)| (df_params['p_slip'] >= 0.5))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# No model degenarcy (CHECK / RUN AGAIN) which is good, graph shows same pattern and initial learning is pretty normally distributed around 50% across the skills, p_transit is a little lower

# %%
df_params.describe()
# Out:
#            p_init   p_transit     p_guess      p_slip
# count  188.000000  188.000000  188.000000  188.000000
# mean     0.492763    0.322921    0.229220    0.185525
# std      0.124920    0.110086    0.054885    0.050220
# min      0.134969    0.113345    0.008499    0.005906
# 25%      0.409111    0.257314    0.195770    0.159013
# 50%      0.499019    0.319682    0.231576    0.190448
# 75%      0.569397    0.387780    0.268905    0.224276
# max      0.854836    0.643376    0.358141    0.291610

# %% [markdown]
# ## Training the Model
#
# In training the model, each student's learning for each skill is tracked and updated as new observable states come in. This will allow for the skill-specific parameters to be tested and for correctness of a skill for a given student to be predicted as well.
#
# Updating student skill parameters $p(L_t)^k_u$ representing the probability of skill mastery for skill $k$ and student $u$ at observation $t$ in the skill is as follows:
#
# (1) $$p(L_1)^k_u = p(L_0)^k$$
#
#
# (2) $$p(L_{t+1} | obs = correct)^k_u = \frac{p(L_t)^k_u \cdot (1 - p(S)^k)}{p(L_t)^k_u \cdot (1 - p(S)^k) + (1 - p(L_t)^k_u) \cdot p(G)^k}$$
#
#
# (3) $$p(L_{t+1} | obs = wrong)^k_u = \frac{p(L_t)^k_u \cdot p(S)^k}{p(L_t)^k_u \cdot p(S)^k + (1 - p(L_t)^k_u) \cdot (1 - p(G)^k)}$$
#
#
# (4) $$p(L_{t+1})^k_u = p(L_{t+1} | obs)^k_u + (1 - p(L_{t+1} | obs)^k_u) \cdot p(T)^k$$
#
#
# (5) $$p(C_{t+1})^k_u = p(L_t)^k_u \cdot (1 - p(S)^k) + (1 - p(L_t)^k_u) \cdot p(G)^k$$
#
#
# Where equation (1) is used as the a priori knowledge of a skill, equations (2) and (3) are conditional probabilities of student mastery of the skill given their answer (correct/incorrect) to a question of that skill, equation (4) is used to update the probability of student mastery of that skill, and equation (5) is for predictions of how the student will perform on subsequent questions within that skill

# %%
class BKTModel:
    
    def __init__(self, skill_params, q_tags):
        self.skill_params = skill_params
        self.users = dict() # form: {user_id : {skill: .1, skill2: .9, etc}}
        self.questions = q_tags
    
    # eq 1
    def get_prior(self, skill):
        return self.skill_params[skill]['p_init']
    
    def get_user_skill(self, user, skill):
        """
        Gets the p(L) of a user for given skill, initializes the user/skill if not already in self.users
        """
        if user not in self.users.keys():
            self.users[user] = dict()
        if skill not in self.users[user]:
            self.users[user][skill] = self.get_prior(skill)
        return self.users[user][skill]
    
    def train(self, df):
        """
        To train the model 
        
        parameters
        ----------
        df : pandas dataframe of training data where each row corresponds to an event/observation
        """
        # helper functions corresponding to above equations
        # eq 2
        def cond_correct(user, skill):
            pL = self.get_user_skill(user, skill)
            top = pL * (1 - self.skill_params[skill]['p_slip'])
            bottom = top + ((1 - pL) * self.skill_params[skill]['p_guess'])
            return top / bottom
        # eq 3
        def cond_wrong(user, skill):
            pL = self.get_user_skill(user, skill)
            top = pL * self.skill_params[skill]['p_slip']
            bottom = top + ((1 - pL) * (1 - self.skill_params[skill]['p_guess']))
            return top / bottom
        # eq 4, calls 2 or 3
        # 'correct' is bool (0=false/1=true)
        def update_knowledge(user, skill, correct):
            if correct:
                cond_pL = cond_correct(user, skill)
            else:
                cond_pL = cond_wrong(user, skill)
            self.users[user][skill] = cond_pL + ((1 - cond_pL) * self.skill_params[skill]['p_transit'])
            
        # main training loop
        print('BEGINNING TRAINING --------------------------------------------------------------')
        start = time.time()
        for i,row in df.iterrows():
            tags = self.questions[row['content_id']]
            for tag in tags:
                if tag == '-1':
                    continue
                update_knowledge(row['user_id'], tag, row['answered_correctly'])
            
            if i % 1000000 == 0:
                print('Iteration {} done -------------------- Time elapsed: {} seconds'.format(i, time.time() - start))
                start = time.time()
                
    # eq 5
    def predict(self, user, skill):
        """
        Function to predict correctness of a single user to answering a question within a skill
        """
        pL = self.get_user_skill(user, skill)
        return (pL * (1 - self.skill_params[skill]['p_slip'])) + ((1 - pL) * self.skill_params[skill]['p_guess'])
    
    def test(self, df, cutoff, confusion_mat=True, raw_probs=True):
        """
        Function to run predictions on testing data. 
        If a question has multiple tags then I take the average of those predictions
        
        parameters
        ----------
        df : pandas dataframe with testing data, must be in format where 1 row = 1 observation
        cutoff : cutoff probability to be marked as correct (ie if 0.5 then everything >= 0.5 = correct)
        confusion_mat : whether to return a confusion matrix plot, default True
        raw_probs : whether to return the raw probabilities (before casting to 0/1 based on cutoff), default True
        
        returns
        --------
        df_test : test dataframe with predicted correct/incorrect column
                    also includes raw_probability column if param is True
        accuracy : computed accuracy
        confusion : confusion matrix visualization
        """
        
        predicted = []
        raw_probability = []
        for i,row in df.iterrows():
            tags = self.questions[row['content_id']]
            tot = 0
            for tag in tags:
                tot += self.predict(row['user_id'], tag)
            raw_probability.append(tot / len(tags))
            predicted.append(int((tot/len(tags)) > cutoff))
        
        df_test = df.copy()
        df_test['predicted'] = predicted
        if raw_probs:
            df_test['raw_probability'] = raw_probability
        accuracy = sklearn.metrics.accuracy_score(df_test['answered_correctly'].values, predicted)
        
        if confusion_mat:
            confusion = sklearn.metrics.confusion_matrix(df_test['answered_correctly'].values, predicted)
            categories = ['incorrect', 'correct']
            confusion_viz = make_confusion_matrix(confusion, categories=categories)
            return df_test, accuracy, confusion_viz
        return df_test, accuracy

# %%
# initialize model
q_tags = dict(zip(df_questions['question_id'], df_questions['tags']))
params = params
BKT = BKTModel(params, q_tags)

# %%
# ONLY RUN ONCE AND SAVE DATA
BKT.train(df_train)

# save user params
# SPLIT INTO MULTIPLE WHEN SAVING OR EVERYTHING WILL GO TO HELL AND CRASH LIKE LAST TIME AND YOULL HAVE TO RETYPE EVERYTHING
with open('users_trained.json', 'w') as json_file:
    json.dump(BKT.users, json_file)

# %%
# get user parameters again (PROB NEED TO CHANGE FOR MULTIPLE FILES)
f = open('users_trained.json')
BKT.users = json.load(f)

# %%
# # SPLITTING INTO MULTIPLE FILES FOR UPLOAD
# for i,(k,v) in enumerate(BKT.users.item()):
#     if i % 59531 == 0:
#         if i != 0:
#             with open(name, 'w') as json_file:
#                 json.dump(group, json_file)
#             print('{} done'.format(i/59531))
#         group = dict()
#         name = 'users_trained_{}.json'.format(int(i/59531))
#     group[k] = v
# with open(name, 'w') as json_file:
#     json.dump(group, json_file)

# %% [markdown]
# ## Testing predictions
#
# I kind of miscalculated here and df_test doesn't have the true labels so I can't actually use that ... Instead I'll randomly choose 1% of training users to test on (those users' last row/observation in training)

# %%
df_test
# Out:
#          timestamp     user_id  content_id  user_answer  answered_correctly
# 0        668090043         115        3363            1                   0
# 1        668090043         115        3365            0                   0
# 2        668090043         115        3364            1                   1
# 3           571323         124        7218            3                   0
# 4           571323         124        7216            0                   0
# ...            ...         ...         ...          ...                 ...
# 983914  1470571968  2147482216        1177            3                   1
# 983915  1470594073  2147482216        1399            1                   1
# 983916   428613475  2147482888        4212            3                   1
# 983917   428649406  2147482888        6343            1                   0
# 983918   428692118  2147482888        7995            3                   1
#
# [983919 rows x 5 columns]

# %%
df_results, acc, confusion = BKT.test(df_test, cutoff=0.5)

# %%
print(acc)
# Out:
# 0.5632658785936647

# %%
df_results
# Out:
#          timestamp     user_id  content_id  user_answer  answered_correctly  \
# 0        668090043         115        3363            1                   0
# 1        668090043         115        3365            0                   0
# 2        668090043         115        3364            1                   1
# 3           571323         124        7218            3                   0
# 4           571323         124        7216            0                   0
# ...            ...         ...         ...          ...                 ...
# 983914  1470571968  2147482216        1177            3                   1
# 983915  1470594073  2147482216        1399            1                   1
# 983916   428613475  2147482888        4212            3                   1
# 983917   428649406  2147482888        6343            1                   0
# 983918   428692118  2147482888        7995            3                   1
#
#         predicted  raw_probability
# 0               0         0.374427
# 1               0         0.376048
# 2               0         0.376048
# 3               0         0.443668
# 4               0         0.407358
# ...           ...              ...
# 983914          1         0.535790
# 983915          1         0.541396
# 983916          1         0.585790
# 983917          1         0.512390
# 983918          0         0.447038
#
# [983919 rows x 7 columns]

# %%
# pred correct/incorrect distributions
pred_correct = df_results[df_results['answered_correctly'] == df_results['predicted']]
pred_wrong = df_results[df_results['answered_correctly'] != df_results['predicted']]

plt.scatter(pred_correct['raw_probability'].values, np.random.normal(0,2,len(pred_correct)), marker='.', color='r', label='correct')
plt.scatter(pred_wrong['raw_probability'].values, np.random.normal(0,2,len(pred_wrong)), marker='.', color='b', label='wrong')
plt.legend()
plt.show()

# %%
corr = []
for i,row in df_results.iterrows():
    if row['answered_correctly'] == row['predicted']:
        corr.append('correct')
    else:
        corr.append('incorrect')
df_results['outcome'] = corr

# %%
plt.figure(figsize=(10,10))
sns.displot(data=df_results, x='raw_probability', hue='outcome', kde=True)
plt.show()

# %%
print('Mean probabilities predicted correct: {}'.format(pred_correct['raw_probability'].mean()))
print('Mean probabilities predicted wrong: {}'.format(pred_wrong['raw_probability'].mean()))
# Out:
# Mean probabilities predicted correct: 0.4816950346305947
# Mean probabilities predicted wrong: 0.4802677765449468

# %%
sklearn.metrics.roc_auc_score(df_results['answered_correctly'], df_results['predicted'])
# Out:
# 0.565766576680195
