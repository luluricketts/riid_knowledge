# %% [markdown]
# # Bayesian Knowledge Tracing (initial model)
#
# This notebook consists of a baseline BKT model as defined by Corbett & Anderson 1995. BKT aims to track student knowledge states for a given skill using underlying Hidden Markov Models, where the latent states are knowledge of a skill and observed states are correctness in answering questions related to that skill.
#
# Each skill will be represented as a BKT model with 4 parameters:
# * $p(L_0)$ or p_init_ : a priori knowledge of the skill (before any practice)
# * $p(T)$ or p_transit : probability of transitioning from the unknown to known state for that concept
# * $p(G)$ or p_guess : probability of answering a question correct if the skill is in the unknown state
# * $p(S)$ or p_slip : probability of answering a question wrong if the skill is in the known state
#
# And each student will have their own parameter subset $p(L_t)^k$ for each skill $k$ as they answer $t$ questions, which will be updated at each time point (question) $t$ per skill

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import time
import sklearn
from sklearn import metrics
import sys
sys.path.append('../')
from df_matrix import make_confusion

# %% [markdown]
# ## Loading data:
#
# Loading all the dataframes here although I won't be looking at the lectures metadata for this model. Testing data will be used only for assessing model accuracy while training the models will use both the training and questions metadata.

# %%
# load data
data_dir = './data/'

start = time.time()
df_train = pd.read_csv(data_dir + 'train.csv')
print('Training Data Loaded, time elapsed:', round(time.time() - start, 3), 'seconds')
df_lectures = pd.read_csv(data_dir + 'lectures.csv')
df_questions = pd.read_csv(data_dir + 'questions.csv')
df_test = pd.read_csv(data_dir + 'example_test.csv')

print('All Dataframes Loaded ------------------------------')
# Out:
# Training Data Loaded, time elapsed: 99.309 seconds
# All Dataframes Loaded ------------------------------

# %% [markdown]
# ### Viewing initial dataframes

# %%
df_train
# Out:
#               row_id  timestamp     user_id  content_id  content_type_id  \
# 0                  0          0         115        5692                0
# 1                  1      56943         115        5716                0
# 2                  2     118363         115         128                0
# 3                  3     131167         115        7860                0
# 4                  4     137965         115        7922                0
# ...              ...        ...         ...         ...              ...
# 101230327  101230327  428564420  2147482888        3586                0
# 101230328  101230328  428585000  2147482888        6341                0
# 101230329  101230329  428613475  2147482888        4212                0
# 101230330  101230330  428649406  2147482888        6343                0
# 101230331  101230331  428692118  2147482888        7995                0
#
#            task_container_id  user_answer  answered_correctly  \
# 0                          1            3                   1
# 1                          2            2                   1
# 2                          0            0                   1
# 3                          3            0                   1
# 4                          4            1                   1
# ...                      ...          ...                 ...
# 101230327                 22            0                   1
# 101230328                 23            3                   1
# 101230329                 24            3                   1
# 101230330                 25            1                   0
# 101230331                 26            3                   1
#
#            prior_question_elapsed_time  prior_question_had_explanation
# 0                                  NaN                            True
# 1                              37000.0                           False
# 2                              55000.0                           False
# 3                              19000.0                           False
# 4                              11000.0                           False
# ...                                ...                             ...
# 101230327                      18000.0                            True
# 101230328                      14000.0                            True
# 101230329                      14000.0                            True
# 101230330                      22000.0                            True
# 101230331                      29000.0                            True
#
# [101230332 rows x 10 columns]

# %%
df_questions
# Out:
#        question_id  bundle_id  correct_answer  part            tags
# 0                0          0               0     1   51 131 162 38
# 1                1          1               1     1       131 36 81
# 2                2          2               0     1  131 101 162 92
# 3                3          3               0     1  131 149 162 29
# 4                4          4               3     1    131 5 162 38
# ...            ...        ...             ...   ...             ...
# 13518        13518      13518               3     5              14
# 13519        13519      13519               3     5               8
# 13520        13520      13520               2     5              73
# 13521        13521      13521               0     5             125
# 13522        13522      13522               3     5              55
#
# [13523 rows x 5 columns]

# %% [markdown]
# ### Cleaning

# %%
# dropping unneeded columns from train
dropcols = ['row_id', 'task_container_id', 'prior_question_elapsed_time', 'prior_question_had_explanation']
df_train.drop(dropcols, axis=1, inplace=True)

# %%
# since we aren't looking at lectures, I'm restricting training data to exclude lectures (content_type_id = 1)
print('Dropping {} rows...'.format(len(df_train[df_train['content_type_id'] == 1])))
df_train = df_train[df_train['content_type_id'] == 0]
# Out:
# Dropping 1959032 rows...

# %%
# can drop content_type_id now because they're all the same value (0)
df_train.drop('content_type_id', axis=1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# dropping bundle_id and part from questions
# bundle_id represents which questions are shown together and may be used for future modifications of the model,
#  but different bundles don't seem to correspond to different tags so I won't use them here
# part corresponds to a higher level type of question ranging rom 1-5 that are too broad for this analysis
dropcols = ['bundle_id', 'part']
df_questions.drop(dropcols, axis=1, inplace=True)

# %%
# changing 'tags' column to a list structure so its easier to query later on and setting null value to -1
df_questions['tags'].fillna('-1', inplace=True)
df_questions['tags'] = df_questions['tags'].str.split()

# %% [markdown]
# ### Viewing cleaned dataframes

# %%
df_train
# Out:
#            timestamp     user_id  content_id  user_answer  answered_correctly
# 0                  0         115        5692            3                   1
# 1              56943         115        5716            2                   1
# 2             118363         115         128            0                   1
# 3             131167         115        7860            0                   1
# 4             137965         115        7922            1                   1
# ...              ...         ...         ...          ...                 ...
# 101230327  428564420  2147482888        3586            0                   1
# 101230328  428585000  2147482888        6341            3                   1
# 101230329  428613475  2147482888        4212            3                   1
# 101230330  428649406  2147482888        6343            1                   0
# 101230331  428692118  2147482888        7995            3                   1
#
# [99271300 rows x 5 columns]

# %%
df_questions
# Out:
#        question_id  correct_answer                 tags
# 0                0               0   [51, 131, 162, 38]
# 1                1               1        [131, 36, 81]
# 2                2               0  [131, 101, 162, 92]
# 3                3               0  [131, 149, 162, 29]
# 4                4               3    [131, 5, 162, 38]
# ...            ...             ...                  ...
# 13518        13518               3                 [14]
# 13519        13519               3                  [8]
# 13520        13520               2                 [73]
# 13521        13521               0                [125]
# 13522        13522               3                 [55]
#
# [13523 rows x 3 columns]

# %%
df_questions[df_questions['question_id'] == 7922]
# Out:
#       question_id  correct_answer            tags
# 7922         7922               1  [131, 149, 92]

# %% [markdown]
# ## Fitting skill parameters
#
# These seems to be a few ways in the literature about how one can do this: EM, brute-force search, and conjugate gradient search have all been done. Here, I've chosen to use the **Empirical Probabilities** approach as defined in Hawkins, Heffernan, and Baker 2011, where they shown that this way of initializing the model parameters resulted in statistically significant increase in model performance.
#
# In this model the skill parameters will not change with training and will remain constant across time and students...future direction will include accounting for student-specific parameters and potentially modifying those parameters as needed for training.
#
# ### Computing knowledge sequences
#
# The first step in the empirical probabilities approach to fitting skill parameters is to compute 'knowledge sequences' for each skill for each student. I am treating each separate 'tag' as its own skill, and questions that have multiple tags will count towards the knowledge sequences for all of the tags.
#
# Additionally for each skill, each student has their own knowledge sequence and all the knowledge sequences for a skill will be used to calculate that skill's BKT parameters

# %%
def get_knowledge_sequence(response):
    """
    Given a list of student responses to questions within a skill, this function computes the 
    knowledge sequence defined by Hawkins et al. (2011)
    This function (1) computes all knowledge permuatations of the length of the student's responses, where
    these permutations have the condition that a wrong answer cannot come after a right answer (no forgetting), 
    then (2) matches the responses to the permutation that's most similar and returns that sequence.
    If there is a tie, the average is taken
    
    Parameters
    ----------
    responses: sequence of student's answers to questions (correct/incorrect) as binary sequence
    
    Returns
    -------
    sequence: binary knowledge sequence where change from 0->1 signifies transition to learned state
    
    """
    l = len(response)
    maxs = []
    maxacc = 0
    
    def accuracy(resp, perm):
        """Get accuracy of student response and a given permutation"""
        unit = 1 / l
        acc = 0
        for i in range(l):
            if resp[i] == perm[i]:
                acc += unit
        return acc
    
    for i in range(l+1):
        perm = ([0] * (l-i)) + ([1] * i)
        if accuracy(response, perm) > maxacc:
            maxacc = accuracy(response, perm)
            maxs = [perm]
        elif accuracy(response, perm) == maxacc:
            maxs.append(perm)
    
    if len(maxs) == 1:
        return maxs[0]
    else:
        maxs = np.array(maxs)
        return list(maxs.mean(axis=0))

# %%
def get_all_sequences(df_train):
    """
    Function to get all of the knowledge sequences given the training data by going through each student
    and recording correctness to answers in each skill (tag), then calls get_knowledge_sequence to compute
    the knowledge sequences for each skill
    
    Params
    -------
    df_train : training dataframe
    
    Returns
    --------
    responses : raw correct/incorrect sequences for each skill
    sequences : dict of knowledge sequences per skill, where keys are a skill and values are a list of 
                knowledge sequences for that skill (1 per student who was tested on the skill)
    """
    print('TOTAL USERS: {}'.format(len(df_train['user_id'].unique())))
    start = time.time()
    
    # construct student responses for each tag
    responses = dict() # correctness (binary) scores
    sequences = dict() # knowledge sequences
    for n,user in enumerate(df_train['user_id'].unique()):

        # for each interaction of this user
        stuseentags = [] # tags that students has a running score for
        for i,row in df_train[df_train['user_id'] == user].sort_values(by='timestamp').iterrows():
            tags = df_questions.loc[df_questions['question_id'] == row['content_id'], 'tags'].values[0]

            for t in tags:
                responses[t] = responses.get(t, []) # initializes a list if its a new tag
                if t not in stuseentags:
                    stuseentags.append(t)
                    responses[t].append([row['answered_correctly']])
                else:
                    responses[t][-1].append(row['answered_correctly'])
                    
        for tag in stuseentags:
            sequences[tag] = sequences.get(tag, [])
            sequences[tag].append(get_knowledge_sequence(responses[tag][-1]))
        
        if n % 50 == 0:
            print('USER {} COMPLETED----------------\tTime Elapsed: {} seconds'.format(n, time.time() - start))
            start = time.time()
            #break
    
    return responses,sequences

# %% [markdown]
# ### Fitting parameters to each skill
#
# Given the responses and knowledge sequences, I'm going to fit the parameters for each skill using the following equations (as given by Hawkins 2011):
#
# $$p(L_0) = \frac{\sum{K_0}}{|K_0|}$$
#
#
# $$p(T) = \frac{\sum_{i!=0}{(1-K_{i-1})}K_i}{\sum_{i!=0}{(1-K_{i-1})}}$$
#
#
# $$p(G) = \frac{\sum_iC_i(1-K_i)}{\sum_i (1-K_i)}$$
#
#
# $$p(S) = \frac{\sum_i (1-C_i)K_i}{\sum_i K_i}$$

# %%
### CALL THIS FUNCTION TO FIT PARAMS, ALL OTHER FUNCS ARE ENCAPSULATED IN HERE
###########################################################################################
## DO NOT DO NOT DO NOT CALL THIS FUNCTION AGAIN -- PARAMS ARE STORED IN JSON FILE ########
###########################################################################################
def fit_params_EP(df_train):
    """
    Wrapper function to fit parameters, calls all other functions necessary and then computes 4 parameters
    per skill using the Empirical Probabilities method (Hawkins 2011)
    
    Parameters
    ---------
    df_train : training dataframe to work with
    
    Returns
    --------
    params :  dict where keys are skill tags, values are a dict of the 4 parameters 
                    (p_init, p_transit, p_guess, p_slip)
    """
    
    C, K = get_all_sequences(df_train)
    
    params = dict()
    for key in C.keys():
        p = dict()

        p['p_init'] = sum([i[0] for i in K[key]]) / len(K[key])

        pt_n, pt_d = 0,0
        pg_n, pg_d = 0,0
        ps_n, ps_d = 0,0

        for i in range(len(max(K[key], key=len))):
            for seq in range(len(K[key])):
                if len(K[key][seq]) <= i:
                    continue
                if i > 0:
                    pt_n += (1-K[key][seq][i-1]) * K[key][seq][i]
                    pt_d += (1-K[key][seq][i-1])
                pg_n += C[key][seq][i] * (1-K[key][seq][i])
                pg_d += 1-K[key][seq][i]
                ps_n += (1-C[key][seq][i]) * K[key][seq][i]
                ps_d += K[key][seq][i]

        p['p_transit'] = pt_n / pt_d if pt_d != 0 else 0
        p['p_guess'] = pg_n / pg_d if pg_d != 0 else 0
        p['p_slip'] = ps_n / ps_d if pg_d != 0 else 0

        params[key] = p
    
    return params

# %%
params = fit_params_EP(df_train)
# Out:
# TOTAL USERS: 393656
# USER 0 COMPLETED----------------	Time Elapsed: 0.5103628635406494 seconds
# USER 50 COMPLETED----------------	Time Elapsed: 18.889617919921875 seconds
# USER 100 COMPLETED----------------	Time Elapsed: 8.000968933105469 seconds
# USER 150 COMPLETED----------------	Time Elapsed: 7.617388963699341 seconds
# USER 200 COMPLETED----------------	Time Elapsed: 10.599833250045776 seconds
# USER 250 COMPLETED----------------	Time Elapsed: 26.505836009979248 seconds
# USER 300 COMPLETED----------------	Time Elapsed: 11.562517166137695 seconds
# USER 350 COMPLETED----------------	Time Elapsed: 15.818172931671143 seconds
# USER 400 COMPLETED----------------	Time Elapsed: 8.32919192314148 seconds
# USER 450 COMPLETED----------------	Time Elapsed: 14.301331043243408 seconds
# USER 500 COMPLETED----------------	Time Elapsed: 16.043160915374756 seconds
# USER 550 COMPLETED----------------	Time Elapsed: 8.181124925613403 seconds
# USER 600 COMPLETED----------------	Time Elapsed: 11.725650787353516 seconds
# USER 650 COMPLETED----------------	Time Elapsed: 10.645757913589478 seconds
# USER 700 COMPLETED----------------	Time Elapsed: 21.76968812942505 seconds
# USER 750 COMPLETED----------------	Time Elapsed: 13.570616960525513 seconds
# USER 800 COMPLETED----------------	Time Elapsed: 21.40944790840149 seconds
# USER 850 COMPLETED----------------	Time Elapsed: 13.236576795578003 seconds
# USER 900 COMPLETED----------------	Time Elapsed: 14.069770097732544 seconds
# USER 950 COMPLETED----------------	Time Elapsed: 8.529546976089478 seconds
# USER 1000 COMPLETED----------------	Time Elapsed: 19.242789030075073 seconds
# USER 1050 COMPLETED----------------	Time Elapsed: 7.741538047790527 seconds
# USER 1100 COMPLETED----------------	Time Elapsed: 10.588520050048828 seconds
# USER 1150 COMPLETED----------------	Time Elapsed: 9.674974918365479 seconds
# USER 1200 COMPLETED----------------	Time Elapsed: 15.748048782348633 seconds
# USER 1250 COMPLETED----------------	Time Elapsed: 12.97948694229126 seconds
# USER 1300 COMPLETED----------------	Time Elapsed: 19.74445414543152 seconds
# USER 1350 COMPLETED----------------	Time Elapsed: 10.415815830230713 seconds
# USER 1400 COMPLETED----------------	Time Elapsed: 9.13183879852295 seconds
# USER 1450 COMPLETED----------------	Time Elapsed: 9.514596700668335 seconds
# USER 1500 COMPLETED----------------	Time Elapsed: 7.089807748794556 seconds
# USER 1550 COMPLETED----------------	Time Elapsed: 15.545814037322998 seconds
# USER 1600 COMPLETED----------------	Time Elapsed: 12.966133117675781 seconds
# USER 1650 COMPLETED----------------	Time Elapsed: 18.680261850357056 seconds
# USER 1700 COMPLETED----------------	Time Elapsed: 12.717270135879517 seconds
# USER 1750 COMPLETED----------------	Time Elapsed: 17.55113911628723 seconds
# USER 1800 COMPLETED----------------	Time Elapsed: 9.00373387336731 seconds
# USER 1850 COMPLETED----------------	Time Elapsed: 17.53365182876587 seconds
# USER 1900 COMPLETED----------------	Time Elapsed: 6.764379024505615 seconds
# USER 1950 COMPLETED----------------	Time Elapsed: 9.907801151275635 seconds
# USER 2000 COMPLETED----------------	Time Elapsed: 10.211209058761597 seconds
# USER 2050 COMPLETED----------------	Time Elapsed: 7.3912200927734375 seconds
# USER 2100 COMPLETED----------------	Time Elapsed: 15.269032001495361 seconds
# USER 2150 COMPLETED----------------	Time Elapsed: 14.066437005996704 seconds
# USER 2200 COMPLETED----------------	Time Elapsed: 14.290955066680908 seconds
# USER 2250 COMPLETED----------------	Time Elapsed: 11.86636209487915 seconds
# USER 2300 COMPLETED----------------	Time Elapsed: 13.849072217941284 seconds
# USER 2350 COMPLETED----------------	Time Elapsed: 10.96829605102539 seconds
# USER 2400 COMPLETED----------------	Time Elapsed: 6.925147771835327 seconds
# USER 2450 COMPLETED----------------	Time Elapsed: 14.601022958755493 seconds
# USER 2500 COMPLETED----------------	Time Elapsed: 9.699963331222534 seconds
# USER 2550 COMPLETED----------------	Time Elapsed: 10.361785888671875 seconds
# USER 2600 COMPLETED----------------	Time Elapsed: 8.257092952728271 seconds
# USER 2650 COMPLETED----------------	Time Elapsed: 10.26076602935791 seconds
# USER 2700 COMPLETED----------------	Time Elapsed: 9.990653038024902 seconds
# USER 2750 COMPLETED----------------	Time Elapsed: 7.15145206451416 seconds
# USER 2800 COMPLETED----------------	Time Elapsed: 8.68796682357788 seconds
# USER 2850 COMPLETED----------------	Time Elapsed: 21.73509907722473 seconds
# USER 2900 COMPLETED----------------	Time Elapsed: 20.42309594154358 seconds
# USER 2950 COMPLETED----------------	Time Elapsed: 15.097898960113525 seconds
# USER 3000 COMPLETED----------------	Time Elapsed: 10.52824091911316 seconds
# USER 3050 COMPLETED----------------	Time Elapsed: 11.963399171829224 seconds
# USER 3100 COMPLETED----------------	Time Elapsed: 13.625796794891357 seconds
# USER 3150 COMPLETED----------------	Time Elapsed: 7.0768821239471436 seconds
# USER 3200 COMPLETED----------------	Time Elapsed: 9.747629165649414 seconds
# USER 3250 COMPLETED----------------	Time Elapsed: 6.707780122756958 seconds
# USER 3300 COMPLETED----------------	Time Elapsed: 11.689325094223022 seconds
# USER 3350 COMPLETED----------------	Time Elapsed: 15.549450635910034 seconds
# USER 3400 COMPLETED----------------	Time Elapsed: 7.41683292388916 seconds
# USER 3450 COMPLETED----------------	Time Elapsed: 14.616715908050537 seconds
# USER 3500 COMPLETED----------------	Time Elapsed: 12.055012941360474 seconds
# USER 3550 COMPLETED----------------	Time Elapsed: 6.562008857727051 seconds
# USER 3600 COMPLETED----------------	Time Elapsed: 23.564640045166016 seconds
# USER 3650 COMPLETED----------------	Time Elapsed: 14.087483882904053 seconds
# USER 3700 COMPLETED----------------	Time Elapsed: 10.557705879211426 seconds
# USER 3750 COMPLETED----------------	Time Elapsed: 7.706829071044922 seconds
# USER 3800 COMPLETED----------------	Time Elapsed: 10.376744031906128 seconds
# USER 3850 COMPLETED----------------	Time Elapsed: 12.306118726730347 seconds
# USER 3900 COMPLETED----------------	Time Elapsed: 11.903768062591553 seconds
# USER 3950 COMPLETED----------------	Time Elapsed: 16.635677814483643 seconds
# USER 4000 COMPLETED----------------	Time Elapsed: 10.43315577507019 seconds
# USER 4050 COMPLETED----------------	Time Elapsed: 7.576758146286011 seconds
# USER 4100 COMPLETED----------------	Time Elapsed: 9.177103757858276 seconds
# USER 4150 COMPLETED----------------	Time Elapsed: 8.903368949890137 seconds
# USER 4200 COMPLETED----------------	Time Elapsed: 12.680338859558105 seconds
# USER 4250 COMPLETED----------------	Time Elapsed: 21.861369848251343 seconds
# USER 4300 COMPLETED----------------	Time Elapsed: 16.983792066574097 seconds
# USER 4350 COMPLETED----------------	Time Elapsed: 9.414890050888062 seconds
# USER 4400 COMPLETED----------------	Time Elapsed: 11.447616815567017 seconds
# USER 4450 COMPLETED----------------	Time Elapsed: 8.421149969100952 seconds
# USER 4500 COMPLETED----------------	Time Elapsed: 10.926280975341797 seconds
# USER 4550 COMPLETED----------------	Time Elapsed: 11.75206208229065 seconds
# USER 4600 COMPLETED----------------	Time Elapsed: 10.8824942111969 seconds
# USER 4650 COMPLETED----------------	Time Elapsed: 26.1112277507782 seconds
# USER 4700 COMPLETED----------------	Time Elapsed: 11.489664077758789 seconds
# USER 4750 COMPLETED----------------	Time Elapsed: 9.020360946655273 seconds
# USER 4800 COMPLETED----------------	Time Elapsed: 7.962140798568726 seconds
# USER 4850 COMPLETED----------------	Time Elapsed: 7.700083017349243 seconds
# USER 4900 COMPLETED----------------	Time Elapsed: 8.633944034576416 seconds
# USER 4950 COMPLETED----------------	Time Elapsed: 7.308876037597656 seconds
# USER 5000 COMPLETED----------------	Time Elapsed: 9.848824977874756 seconds
# USER 5050 COMPLETED----------------	Time Elapsed: 7.925938844680786 seconds
# USER 5100 COMPLETED----------------	Time Elapsed: 10.52609896659851 seconds
# USER 5150 COMPLETED----------------	Time Elapsed: 19.170781135559082 seconds
# USER 5200 COMPLETED----------------	Time Elapsed: 9.905776977539062 seconds
# USER 5250 COMPLETED----------------	Time Elapsed: 12.846123933792114 seconds
# USER 5300 COMPLETED----------------	Time Elapsed: 9.302849054336548 seconds
# USER 5350 COMPLETED----------------	Time Elapsed: 6.438094854354858 seconds
# USER 5400 COMPLETED----------------	Time Elapsed: 9.920546054840088 seconds
# USER 5450 COMPLETED----------------	Time Elapsed: 9.546301126480103 seconds
# USER 5500 COMPLETED----------------	Time Elapsed: 15.705229043960571 seconds
# USER 5550 COMPLETED----------------	Time Elapsed: 22.94161105155945 seconds
# USER 5600 COMPLETED----------------	Time Elapsed: 13.228131771087646 seconds
# USER 5650 COMPLETED----------------	Time Elapsed: 14.645938158035278 seconds
# USER 5700 COMPLETED----------------	Time Elapsed: 10.36799693107605 seconds
# USER 5750 COMPLETED----------------	Time Elapsed: 7.827674865722656 seconds
# USER 5800 COMPLETED----------------	Time Elapsed: 21.30625605583191 seconds
# USER 5850 COMPLETED----------------	Time Elapsed: 7.213042974472046 seconds
# USER 5900 COMPLETED----------------	Time Elapsed: 10.47452712059021 seconds
# USER 5950 COMPLETED----------------	Time Elapsed: 17.51807999610901 seconds
# USER 6000 COMPLETED----------------	Time Elapsed: 7.12023401260376 seconds
# USER 6050 COMPLETED----------------	Time Elapsed: 8.188556909561157 seconds
# USER 6100 COMPLETED----------------	Time Elapsed: 8.514516115188599 seconds
# USER 6150 COMPLETED----------------	Time Elapsed: 17.74999690055847 seconds
# USER 6200 COMPLETED----------------	Time Elapsed: 9.075580835342407 seconds
# USER 6250 COMPLETED----------------	Time Elapsed: 12.281485080718994 seconds
# USER 6300 COMPLETED----------------	Time Elapsed: 10.761167764663696 seconds
# USER 6350 COMPLETED----------------	Time Elapsed: 8.535922765731812 seconds
# USER 6400 COMPLETED----------------	Time Elapsed: 10.500632762908936 seconds
# USER 6450 COMPLETED----------------	Time Elapsed: 15.409785032272339 seconds
# USER 6500 COMPLETED----------------	Time Elapsed: 11.613228797912598 seconds
# USER 6550 COMPLETED----------------	Time Elapsed: 10.53636622428894 seconds
# USER 6600 COMPLETED----------------	Time Elapsed: 23.071753978729248 seconds
# USER 6650 COMPLETED----------------	Time Elapsed: 7.7233500480651855 seconds
# USER 6700 COMPLETED----------------	Time Elapsed: 8.88853406906128 seconds
# USER 6750 COMPLETED----------------	Time Elapsed: 12.681310892105103 seconds
# USER 6800 COMPLETED----------------	Time Elapsed: 11.588581800460815 seconds
# USER 6850 COMPLETED----------------	Time Elapsed: 17.30985426902771 seconds
# USER 6900 COMPLETED----------------	Time Elapsed: 17.02085018157959 seconds
# USER 6950 COMPLETED----------------	Time Elapsed: 7.762124061584473 seconds
# USER 7000 COMPLETED----------------	Time Elapsed: 11.33076810836792 seconds
# USER 7050 COMPLETED----------------	Time Elapsed: 8.242918968200684 seconds
# USER 7100 COMPLETED----------------	Time Elapsed: 14.065466165542603 seconds
# USER 7150 COMPLETED----------------	Time Elapsed: 8.019137144088745 seconds
# USER 7200 COMPLETED----------------	Time Elapsed: 13.974780082702637 seconds
# USER 7250 COMPLETED----------------	Time Elapsed: 9.980488300323486 seconds
# USER 7300 COMPLETED----------------	Time Elapsed: 42.400357723236084 seconds
# USER 7350 COMPLETED----------------	Time Elapsed: 25.453578233718872 seconds
# USER 7400 COMPLETED----------------	Time Elapsed: 8.05406403541565 seconds
# USER 7450 COMPLETED----------------	Time Elapsed: 6.919770002365112 seconds
# USER 7500 COMPLETED----------------	Time Elapsed: 7.401915073394775 seconds
# USER 7550 COMPLETED----------------	Time Elapsed: 11.843674182891846 seconds
# USER 7600 COMPLETED----------------	Time Elapsed: 7.733596086502075 seconds
# USER 7650 COMPLETED----------------	Time Elapsed: 8.91551399230957 seconds
# USER 7700 COMPLETED----------------	Time Elapsed: 7.732119083404541 seconds
# USER 7750 COMPLETED----------------	Time Elapsed: 10.72629714012146 seconds
# USER 7800 COMPLETED----------------	Time Elapsed: 40.35256505012512 seconds
# USER 7850 COMPLETED----------------	Time Elapsed: 12.12337613105774 seconds
# USER 7900 COMPLETED----------------	Time Elapsed: 10.209951162338257 seconds
# USER 7950 COMPLETED----------------	Time Elapsed: 12.618381023406982 seconds
# USER 8000 COMPLETED----------------	Time Elapsed: 9.174585819244385 seconds
# USER 8050 COMPLETED----------------	Time Elapsed: 14.317244052886963 seconds
# USER 8100 COMPLETED----------------	Time Elapsed: 11.287194967269897 seconds
# USER 8150 COMPLETED----------------	Time Elapsed: 8.580554008483887 seconds
# USER 8200 COMPLETED----------------	Time Elapsed: 22.17641305923462 seconds
# USER 8250 COMPLETED----------------	Time Elapsed: 7.815272808074951 seconds
# USER 8300 COMPLETED----------------	Time Elapsed: 9.016662120819092 seconds
# USER 8350 COMPLETED----------------	Time Elapsed: 7.259537220001221 seconds
# USER 8400 COMPLETED----------------	Time Elapsed: 9.848238706588745 seconds
# USER 8450 COMPLETED----------------	Time Elapsed: 14.184059143066406 seconds
# USER 8500 COMPLETED----------------	Time Elapsed: 19.513952016830444 seconds
# USER 8550 COMPLETED----------------	Time Elapsed: 10.200203895568848 seconds
# USER 8600 COMPLETED----------------	Time Elapsed: 7.178200960159302 seconds
# USER 8650 COMPLETED----------------	Time Elapsed: 9.273898839950562 seconds
# USER 8700 COMPLETED----------------	Time Elapsed: 8.076107025146484 seconds
# USER 8750 COMPLETED----------------	Time Elapsed: 7.277881860733032 seconds
# USER 8800 COMPLETED----------------	Time Elapsed: 12.284660339355469 seconds
# USER 8850 COMPLETED----------------	Time Elapsed: 11.020317792892456 seconds
# USER 8900 COMPLETED----------------	Time Elapsed: 7.69856595993042 seconds
# USER 8950 COMPLETED----------------	Time Elapsed: 6.024151086807251 seconds
# USER 9000 COMPLETED----------------	Time Elapsed: 6.505185127258301 seconds
# USER 9050 COMPLETED----------------	Time Elapsed: 9.133264780044556 seconds
# USER 9100 COMPLETED----------------	Time Elapsed: 6.771385669708252 seconds
# USER 9150 COMPLETED----------------	Time Elapsed: 10.272035837173462 seconds
# USER 9200 COMPLETED----------------	Time Elapsed: 8.733777284622192 seconds
# USER 9250 COMPLETED----------------	Time Elapsed: 10.762773990631104 seconds
# USER 9300 COMPLETED----------------	Time Elapsed: 14.500590085983276 seconds
# USER 9350 COMPLETED----------------	Time Elapsed: 11.281393051147461 seconds
# USER 9400 COMPLETED----------------	Time Elapsed: 9.09578013420105 seconds
# USER 9450 COMPLETED----------------	Time Elapsed: 8.522494077682495 seconds
# USER 9500 COMPLETED----------------	Time Elapsed: 11.067689895629883 seconds
# USER 9550 COMPLETED----------------	Time Elapsed: 8.565711975097656 seconds
# USER 9600 COMPLETED----------------	Time Elapsed: 10.504709720611572 seconds
# USER 9650 COMPLETED----------------	Time Elapsed: 6.749971151351929 seconds
# USER 9700 COMPLETED----------------	Time Elapsed: 6.992839813232422 seconds
# USER 9750 COMPLETED----------------	Time Elapsed: 11.078236103057861 seconds
# USER 9800 COMPLETED----------------	Time Elapsed: 10.339972019195557 seconds
# USER 9850 COMPLETED----------------	Time Elapsed: 10.911606073379517 seconds
# USER 9900 COMPLETED----------------	Time Elapsed: 9.57941198348999 seconds
# USER 9950 COMPLETED----------------	Time Elapsed: 9.988324165344238 seconds
# USER 10000 COMPLETED----------------	Time Elapsed: 10.689997911453247 seconds
# USER 10050 COMPLETED----------------	Time Elapsed: 8.354614019393921 seconds
# USER 10100 COMPLETED----------------	Time Elapsed: 8.755791187286377 seconds
# USER 10150 COMPLETED----------------	Time Elapsed: 10.229613065719604 seconds
# USER 10200 COMPLETED----------------	Time Elapsed: 9.363533020019531 seconds
# USER 10250 COMPLETED----------------	Time Elapsed: 10.152437210083008 seconds
# USER 10300 COMPLETED----------------	Time Elapsed: 8.45499300956726 seconds
# USER 10350 COMPLETED----------------	Time Elapsed: 7.082771062850952 seconds
# USER 10400 COMPLETED----------------	Time Elapsed: 7.5034918785095215 seconds
# USER 10450 COMPLETED----------------	Time Elapsed: 8.317933797836304 seconds
# USER 10500 COMPLETED----------------	Time Elapsed: 7.427541017532349 seconds
# USER 10550 COMPLETED----------------	Time Elapsed: 12.576231956481934 seconds
# USER 10600 COMPLETED----------------	Time Elapsed: 12.079714059829712 seconds
# USER 10650 COMPLETED----------------	Time Elapsed: 15.503553628921509 seconds
# USER 10700 COMPLETED----------------	Time Elapsed: 6.901260137557983 seconds
# USER 10750 COMPLETED----------------	Time Elapsed: 9.181588172912598 seconds
# USER 10800 COMPLETED----------------	Time Elapsed: 9.580888986587524 seconds
# USER 10850 COMPLETED----------------	Time Elapsed: 18.037782907485962 seconds
# USER 10900 COMPLETED----------------	Time Elapsed: 13.805954933166504 seconds
# USER 10950 COMPLETED----------------	Time Elapsed: 10.95189094543457 seconds
# USER 11000 COMPLETED----------------	Time Elapsed: 8.859738111495972 seconds
# USER 11050 COMPLETED----------------	Time Elapsed: 9.487212181091309 seconds
# USER 11100 COMPLETED----------------	Time Elapsed: 8.364661931991577 seconds
# USER 11150 COMPLETED----------------	Time Elapsed: 17.377208948135376 seconds
# USER 11200 COMPLETED----------------	Time Elapsed: 9.484593868255615 seconds
# USER 11250 COMPLETED----------------	Time Elapsed: 11.474632024765015 seconds
# USER 11300 COMPLETED----------------	Time Elapsed: 10.821208000183105 seconds
# USER 11350 COMPLETED----------------	Time Elapsed: 7.726414918899536 seconds
# USER 11400 COMPLETED----------------	Time Elapsed: 8.991037130355835 seconds
# USER 11450 COMPLETED----------------	Time Elapsed: 15.268311023712158 seconds
# USER 11500 COMPLETED----------------	Time Elapsed: 12.975765705108643 seconds
# USER 11550 COMPLETED----------------	Time Elapsed: 27.07970690727234 seconds
# USER 11600 COMPLETED----------------	Time Elapsed: 9.695103883743286 seconds
# USER 11650 COMPLETED----------------	Time Elapsed: 10.953914165496826 seconds
# USER 11700 COMPLETED----------------	Time Elapsed: 7.474082708358765 seconds
# USER 11750 COMPLETED----------------	Time Elapsed: 8.345494031906128 seconds
# USER 11800 COMPLETED----------------	Time Elapsed: 9.458307266235352 seconds
# USER 11850 COMPLETED----------------	Time Elapsed: 11.152812957763672 seconds
# USER 11900 COMPLETED----------------	Time Elapsed: 9.496149063110352 seconds
# USER 11950 COMPLETED----------------	Time Elapsed: 14.402934789657593 seconds
# USER 12000 COMPLETED----------------	Time Elapsed: 8.454659700393677 seconds
# USER 12050 COMPLETED----------------	Time Elapsed: 14.550709962844849 seconds
# USER 12100 COMPLETED----------------	Time Elapsed: 12.911072731018066 seconds
# USER 12150 COMPLETED----------------	Time Elapsed: 10.595832109451294 seconds
# USER 12200 COMPLETED----------------	Time Elapsed: 14.677022933959961 seconds
# USER 12250 COMPLETED----------------	Time Elapsed: 21.809814929962158 seconds
# USER 12300 COMPLETED----------------	Time Elapsed: 49.46374011039734 seconds
# USER 12350 COMPLETED----------------	Time Elapsed: 10.542307138442993 seconds
# USER 12400 COMPLETED----------------	Time Elapsed: 10.274487733840942 seconds
# USER 12450 COMPLETED----------------	Time Elapsed: 12.31309175491333 seconds
# USER 12500 COMPLETED----------------	Time Elapsed: 8.683857917785645 seconds
# USER 12550 COMPLETED----------------	Time Elapsed: 11.325975894927979 seconds
# USER 12600 COMPLETED----------------	Time Elapsed: 14.123189926147461 seconds
# USER 12650 COMPLETED----------------	Time Elapsed: 10.537934064865112 seconds
# USER 12700 COMPLETED----------------	Time Elapsed: 8.651253938674927 seconds
# USER 12750 COMPLETED----------------	Time Elapsed: 8.029526710510254 seconds
# USER 12800 COMPLETED----------------	Time Elapsed: 6.963843107223511 seconds
# USER 12850 COMPLETED----------------	Time Elapsed: 18.656540155410767 seconds
# USER 12900 COMPLETED----------------	Time Elapsed: 8.349615812301636 seconds
# USER 12950 COMPLETED----------------	Time Elapsed: 12.79049801826477 seconds
# USER 13000 COMPLETED----------------	Time Elapsed: 11.357836961746216 seconds
# USER 13050 COMPLETED----------------	Time Elapsed: 14.57098126411438 seconds
# USER 13100 COMPLETED----------------	Time Elapsed: 6.231266975402832 seconds
# USER 13150 COMPLETED----------------	Time Elapsed: 9.9789400100708 seconds
# USER 13200 COMPLETED----------------	Time Elapsed: 8.917824983596802 seconds
# USER 13250 COMPLETED----------------	Time Elapsed: 15.761547088623047 seconds
# USER 13300 COMPLETED----------------	Time Elapsed: 9.87687873840332 seconds
# USER 13350 COMPLETED----------------	Time Elapsed: 17.361813068389893 seconds
# USER 13400 COMPLETED----------------	Time Elapsed: 11.809134244918823 seconds
# USER 13450 COMPLETED----------------	Time Elapsed: 10.639823198318481 seconds
# USER 13500 COMPLETED----------------	Time Elapsed: 38.60643935203552 seconds
# USER 13550 COMPLETED----------------	Time Elapsed: 10.847495079040527 seconds
# USER 13600 COMPLETED----------------	Time Elapsed: 8.693947076797485 seconds
# USER 13650 COMPLETED----------------	Time Elapsed: 9.709742069244385 seconds
# USER 13700 COMPLETED----------------	Time Elapsed: 9.097670078277588 seconds
# USER 13750 COMPLETED----------------	Time Elapsed: 12.525881290435791 seconds
# USER 13800 COMPLETED----------------	Time Elapsed: 14.884875059127808 seconds
# USER 13850 COMPLETED----------------	Time Elapsed: 9.696952104568481 seconds
# USER 13900 COMPLETED----------------	Time Elapsed: 9.161120891571045 seconds
# USER 13950 COMPLETED----------------	Time Elapsed: 7.994187116622925 seconds
# USER 14000 COMPLETED----------------	Time Elapsed: 12.241747856140137 seconds
# USER 14050 COMPLETED----------------	Time Elapsed: 14.372822761535645 seconds
# USER 14100 COMPLETED----------------	Time Elapsed: 13.111294984817505 seconds
# USER 14150 COMPLETED----------------	Time Elapsed: 13.54705810546875 seconds
# USER 14200 COMPLETED----------------	Time Elapsed: 7.680399656295776 seconds
# USER 14250 COMPLETED----------------	Time Elapsed: 8.83220386505127 seconds
# USER 14300 COMPLETED----------------	Time Elapsed: 12.266386985778809 seconds
# USER 14350 COMPLETED----------------	Time Elapsed: 7.547921895980835 seconds
# USER 14400 COMPLETED----------------	Time Elapsed: 18.269779920578003 seconds
# USER 14450 COMPLETED----------------	Time Elapsed: 24.820571899414062 seconds
# USER 14500 COMPLETED----------------	Time Elapsed: 8.614444971084595 seconds
# USER 14550 COMPLETED----------------	Time Elapsed: 15.506194114685059 seconds
# USER 14600 COMPLETED----------------	Time Elapsed: 10.359930038452148 seconds
# USER 14650 COMPLETED----------------	Time Elapsed: 11.887106895446777 seconds
# USER 14700 COMPLETED----------------	Time Elapsed: 26.643906116485596 seconds
# USER 14750 COMPLETED----------------	Time Elapsed: 7.568078994750977 seconds
# USER 14800 COMPLETED----------------	Time Elapsed: 23.65229892730713 seconds
# USER 14850 COMPLETED----------------	Time Elapsed: 22.309653997421265 seconds
# USER 14900 COMPLETED----------------	Time Elapsed: 7.222431898117065 seconds
# USER 14950 COMPLETED----------------	Time Elapsed: 8.52783489227295 seconds
# USER 15000 COMPLETED----------------	Time Elapsed: 11.907907009124756 seconds
# USER 15050 COMPLETED----------------	Time Elapsed: 9.02654480934143 seconds
# USER 15100 COMPLETED----------------	Time Elapsed: 30.303082942962646 seconds
# USER 15150 COMPLETED----------------	Time Elapsed: 10.289816856384277 seconds
# USER 15200 COMPLETED----------------	Time Elapsed: 14.806810855865479 seconds
# USER 15250 COMPLETED----------------	Time Elapsed: 13.022218704223633 seconds
# USER 15300 COMPLETED----------------	Time Elapsed: 12.03154182434082 seconds
# USER 15350 COMPLETED----------------	Time Elapsed: 8.12669587135315 seconds
# USER 15400 COMPLETED----------------	Time Elapsed: 11.347110033035278 seconds
# USER 15450 COMPLETED----------------	Time Elapsed: 9.73182487487793 seconds
# USER 15500 COMPLETED----------------	Time Elapsed: 16.92629599571228 seconds
# USER 15550 COMPLETED----------------	Time Elapsed: 10.118328094482422 seconds
# USER 15600 COMPLETED----------------	Time Elapsed: 10.558978080749512 seconds
# USER 15650 COMPLETED----------------	Time Elapsed: 9.425007104873657 seconds
# USER 15700 COMPLETED----------------	Time Elapsed: 9.791819095611572 seconds
# USER 15750 COMPLETED----------------	Time Elapsed: 12.551397800445557 seconds
# USER 15800 COMPLETED----------------	Time Elapsed: 7.951136827468872 seconds
# USER 15850 COMPLETED----------------	Time Elapsed: 13.321239709854126 seconds
# USER 15900 COMPLETED----------------	Time Elapsed: 12.331108808517456 seconds
# USER 15950 COMPLETED----------------	Time Elapsed: 7.918965578079224 seconds
# USER 16000 COMPLETED----------------	Time Elapsed: 11.577507972717285 seconds
# USER 16050 COMPLETED----------------	Time Elapsed: 17.279163122177124 seconds
# USER 16100 COMPLETED----------------	Time Elapsed: 9.52718210220337 seconds
# USER 16150 COMPLETED----------------	Time Elapsed: 16.873842000961304 seconds
# USER 16200 COMPLETED----------------	Time Elapsed: 9.474750995635986 seconds
# USER 16250 COMPLETED----------------	Time Elapsed: 8.92776608467102 seconds
# USER 16300 COMPLETED----------------	Time Elapsed: 25.416813850402832 seconds
# USER 16350 COMPLETED----------------	Time Elapsed: 16.453560829162598 seconds
# USER 16400 COMPLETED----------------	Time Elapsed: 13.539087057113647 seconds
# USER 16450 COMPLETED----------------	Time Elapsed: 9.755563974380493 seconds
# USER 16500 COMPLETED----------------	Time Elapsed: 8.905380249023438 seconds
# USER 16550 COMPLETED----------------	Time Elapsed: 7.623740196228027 seconds
# USER 16600 COMPLETED----------------	Time Elapsed: 10.104823112487793 seconds
# USER 16650 COMPLETED----------------	Time Elapsed: 8.95186996459961 seconds
# USER 16700 COMPLETED----------------	Time Elapsed: 14.48242712020874 seconds
# USER 16750 COMPLETED----------------	Time Elapsed: 11.455104112625122 seconds
# USER 16800 COMPLETED----------------	Time Elapsed: 9.162678003311157 seconds
# USER 16850 COMPLETED----------------	Time Elapsed: 26.016530990600586 seconds
# USER 16900 COMPLETED----------------	Time Elapsed: 22.405910968780518 seconds
# USER 16950 COMPLETED----------------	Time Elapsed: 11.124254941940308 seconds
# USER 17000 COMPLETED----------------	Time Elapsed: 26.301037788391113 seconds
# USER 17050 COMPLETED----------------	Time Elapsed: 8.598448991775513 seconds
# USER 17100 COMPLETED----------------	Time Elapsed: 7.315330743789673 seconds
# USER 17150 COMPLETED----------------	Time Elapsed: 9.167254209518433 seconds
# USER 17200 COMPLETED----------------	Time Elapsed: 26.48441791534424 seconds
# USER 17250 COMPLETED----------------	Time Elapsed: 14.70918869972229 seconds
# USER 17300 COMPLETED----------------	Time Elapsed: 13.05414605140686 seconds
# USER 17350 COMPLETED----------------	Time Elapsed: 11.498059034347534 seconds
# USER 17400 COMPLETED----------------	Time Elapsed: 16.028754949569702 seconds
# USER 17450 COMPLETED----------------	Time Elapsed: 12.303448915481567 seconds
# USER 17500 COMPLETED----------------	Time Elapsed: 12.243257999420166 seconds
# USER 17550 COMPLETED----------------	Time Elapsed: 8.970940828323364 seconds
# USER 17600 COMPLETED----------------	Time Elapsed: 8.60931396484375 seconds
# USER 17650 COMPLETED----------------	Time Elapsed: 8.250516891479492 seconds
# USER 17700 COMPLETED----------------	Time Elapsed: 7.6194891929626465 seconds
# USER 17750 COMPLETED----------------	Time Elapsed: 13.406898975372314 seconds
# USER 17800 COMPLETED----------------	Time Elapsed: 11.593717098236084 seconds
# USER 17850 COMPLETED----------------	Time Elapsed: 13.416448593139648 seconds
# USER 17900 COMPLETED----------------	Time Elapsed: 7.982450008392334 seconds
# USER 17950 COMPLETED----------------	Time Elapsed: 12.607446193695068 seconds
# USER 18000 COMPLETED----------------	Time Elapsed: 7.970960855484009 seconds
# USER 18050 COMPLETED----------------	Time Elapsed: 8.515042066574097 seconds
# USER 18100 COMPLETED----------------	Time Elapsed: 14.369081020355225 seconds
# USER 18150 COMPLETED----------------	Time Elapsed: 6.989699840545654 seconds
# USER 18200 COMPLETED----------------	Time Elapsed: 6.983622312545776 seconds
# USER 18250 COMPLETED----------------	Time Elapsed: 8.354751825332642 seconds
# USER 18300 COMPLETED----------------	Time Elapsed: 18.318517923355103 seconds
# USER 18350 COMPLETED----------------	Time Elapsed: 7.839647054672241 seconds
# USER 18400 COMPLETED----------------	Time Elapsed: 18.814172983169556 seconds
# USER 18450 COMPLETED----------------	Time Elapsed: 7.874011993408203 seconds
# USER 18500 COMPLETED----------------	Time Elapsed: 12.650537967681885 seconds
# USER 18550 COMPLETED----------------	Time Elapsed: 7.881932973861694 seconds
# USER 18600 COMPLETED----------------	Time Elapsed: 8.818304061889648 seconds
# USER 18650 COMPLETED----------------	Time Elapsed: 9.746778726577759 seconds
# USER 18700 COMPLETED----------------	Time Elapsed: 9.347463846206665 seconds
# USER 18750 COMPLETED----------------	Time Elapsed: 9.169896364212036 seconds
# USER 18800 COMPLETED----------------	Time Elapsed: 7.745874881744385 seconds
# USER 18850 COMPLETED----------------	Time Elapsed: 11.348790168762207 seconds
# USER 18900 COMPLETED----------------	Time Elapsed: 8.188804864883423 seconds
# USER 18950 COMPLETED----------------	Time Elapsed: 9.753037929534912 seconds
# USER 19000 COMPLETED----------------	Time Elapsed: 12.202239036560059 seconds
# USER 19050 COMPLETED----------------	Time Elapsed: 9.715415954589844 seconds
# USER 19100 COMPLETED----------------	Time Elapsed: 27.10883116722107 seconds
# USER 19150 COMPLETED----------------	Time Elapsed: 16.989387035369873 seconds
# USER 19200 COMPLETED----------------	Time Elapsed: 9.016390800476074 seconds
# USER 19250 COMPLETED----------------	Time Elapsed: 19.898975372314453 seconds
# USER 19300 COMPLETED----------------	Time Elapsed: 6.97880482673645 seconds
# USER 19350 COMPLETED----------------	Time Elapsed: 7.994816064834595 seconds
# USER 19400 COMPLETED----------------	Time Elapsed: 8.514936208724976 seconds
# USER 19450 COMPLETED----------------	Time Elapsed: 8.286058902740479 seconds
# USER 19500 COMPLETED----------------	Time Elapsed: 8.787065744400024 seconds
# USER 19550 COMPLETED----------------	Time Elapsed: 12.922363996505737 seconds
# USER 19600 COMPLETED----------------	Time Elapsed: 8.782275676727295 seconds
# USER 19650 COMPLETED----------------	Time Elapsed: 7.5881757736206055 seconds
# USER 19700 COMPLETED----------------	Time Elapsed: 9.609879970550537 seconds
# USER 19750 COMPLETED----------------	Time Elapsed: 12.949544906616211 seconds
# USER 19800 COMPLETED----------------	Time Elapsed: 9.069308042526245 seconds
# USER 19850 COMPLETED----------------	Time Elapsed: 13.092568159103394 seconds
# USER 19900 COMPLETED----------------	Time Elapsed: 8.567068099975586 seconds
# USER 19950 COMPLETED----------------	Time Elapsed: 9.05153489112854 seconds
# USER 20000 COMPLETED----------------	Time Elapsed: 9.295169115066528 seconds
# USER 20050 COMPLETED----------------	Time Elapsed: 10.671157836914062 seconds
# USER 20100 COMPLETED----------------	Time Elapsed: 8.154367923736572 seconds
# USER 20150 COMPLETED----------------	Time Elapsed: 10.101317167282104 seconds
# USER 20200 COMPLETED----------------	Time Elapsed: 14.151294946670532 seconds
# USER 20250 COMPLETED----------------	Time Elapsed: 8.329025983810425 seconds
# USER 20300 COMPLETED----------------	Time Elapsed: 18.214693784713745 seconds
# USER 20350 COMPLETED----------------	Time Elapsed: 9.323199033737183 seconds
# USER 20400 COMPLETED----------------	Time Elapsed: 11.046885251998901 seconds
# USER 20450 COMPLETED----------------	Time Elapsed: 31.815216064453125 seconds
# USER 20500 COMPLETED----------------	Time Elapsed: 13.583347797393799 seconds
# USER 20550 COMPLETED----------------	Time Elapsed: 7.545147180557251 seconds
# USER 20600 COMPLETED----------------	Time Elapsed: 6.893972158432007 seconds
# USER 20650 COMPLETED----------------	Time Elapsed: 55.00607204437256 seconds
# USER 20700 COMPLETED----------------	Time Elapsed: 13.955180168151855 seconds
# USER 20750 COMPLETED----------------	Time Elapsed: 8.686887979507446 seconds
# USER 20800 COMPLETED----------------	Time Elapsed: 13.097751140594482 seconds
# USER 20850 COMPLETED----------------	Time Elapsed: 9.66328501701355 seconds
# USER 20900 COMPLETED----------------	Time Elapsed: 9.40029001235962 seconds
# USER 20950 COMPLETED----------------	Time Elapsed: 10.09477186203003 seconds
# USER 21000 COMPLETED----------------	Time Elapsed: 9.115877866744995 seconds
# USER 21050 COMPLETED----------------	Time Elapsed: 8.42652702331543 seconds
# USER 21100 COMPLETED----------------	Time Elapsed: 7.251373052597046 seconds
# USER 21150 COMPLETED----------------	Time Elapsed: 8.339820146560669 seconds
# USER 21200 COMPLETED----------------	Time Elapsed: 12.949702978134155 seconds
# USER 21250 COMPLETED----------------	Time Elapsed: 6.900296926498413 seconds
# USER 21300 COMPLETED----------------	Time Elapsed: 10.695620059967041 seconds
# USER 21350 COMPLETED----------------	Time Elapsed: 16.17902398109436 seconds
# USER 21400 COMPLETED----------------	Time Elapsed: 8.161367893218994 seconds
# USER 21450 COMPLETED----------------	Time Elapsed: 8.005249738693237 seconds
# USER 21500 COMPLETED----------------	Time Elapsed: 13.086153030395508 seconds
# USER 21550 COMPLETED----------------	Time Elapsed: 18.77012300491333 seconds
# USER 21600 COMPLETED----------------	Time Elapsed: 9.201271057128906 seconds
# USER 21650 COMPLETED----------------	Time Elapsed: 12.348721265792847 seconds
# USER 21700 COMPLETED----------------	Time Elapsed: 24.854341983795166 seconds
# USER 21750 COMPLETED----------------	Time Elapsed: 7.6481640338897705 seconds
# USER 21800 COMPLETED----------------	Time Elapsed: 14.897567987442017 seconds
# USER 21850 COMPLETED----------------	Time Elapsed: 8.420233011245728 seconds
# USER 21900 COMPLETED----------------	Time Elapsed: 37.05901789665222 seconds
# USER 21950 COMPLETED----------------	Time Elapsed: 7.2752439975738525 seconds
# USER 22000 COMPLETED----------------	Time Elapsed: 7.84771203994751 seconds
# USER 22050 COMPLETED----------------	Time Elapsed: 8.708968877792358 seconds
# USER 22100 COMPLETED----------------	Time Elapsed: 10.06744384765625 seconds
# USER 22150 COMPLETED----------------	Time Elapsed: 7.905030012130737 seconds
# USER 22200 COMPLETED----------------	Time Elapsed: 7.672359228134155 seconds
# USER 22250 COMPLETED----------------	Time Elapsed: 6.797757863998413 seconds
# USER 22300 COMPLETED----------------	Time Elapsed: 9.814925909042358 seconds
# USER 22350 COMPLETED----------------	Time Elapsed: 13.774972915649414 seconds
# USER 22400 COMPLETED----------------	Time Elapsed: 11.779500961303711 seconds
# USER 22450 COMPLETED----------------	Time Elapsed: 9.030147075653076 seconds
# USER 22500 COMPLETED----------------	Time Elapsed: 9.74677300453186 seconds
# USER 22550 COMPLETED----------------	Time Elapsed: 12.230464935302734 seconds
# USER 22600 COMPLETED----------------	Time Elapsed: 10.028119087219238 seconds
# USER 22650 COMPLETED----------------	Time Elapsed: 6.558811187744141 seconds
# USER 22700 COMPLETED----------------	Time Elapsed: 7.93337082862854 seconds
# USER 22750 COMPLETED----------------	Time Elapsed: 18.232889890670776 seconds
# USER 22800 COMPLETED----------------	Time Elapsed: 13.249273777008057 seconds
# USER 22850 COMPLETED----------------	Time Elapsed: 8.860553979873657 seconds
# USER 22900 COMPLETED----------------	Time Elapsed: 8.706017017364502 seconds
# USER 22950 COMPLETED----------------	Time Elapsed: 8.10696816444397 seconds
# USER 23000 COMPLETED----------------	Time Elapsed: 23.764413833618164 seconds
# USER 23050 COMPLETED----------------	Time Elapsed: 8.159139633178711 seconds
# USER 23100 COMPLETED----------------	Time Elapsed: 12.615356206893921 seconds
# USER 23150 COMPLETED----------------	Time Elapsed: 10.386736869812012 seconds
# USER 23200 COMPLETED----------------	Time Elapsed: 11.330590009689331 seconds
# USER 23250 COMPLETED----------------	Time Elapsed: 8.54218316078186 seconds
# USER 23300 COMPLETED----------------	Time Elapsed: 9.717464923858643 seconds
# USER 23350 COMPLETED----------------	Time Elapsed: 11.607388019561768 seconds
# USER 23400 COMPLETED----------------	Time Elapsed: 10.108314752578735 seconds
# USER 23450 COMPLETED----------------	Time Elapsed: 6.91920804977417 seconds
# USER 23500 COMPLETED----------------	Time Elapsed: 9.842798948287964 seconds
# USER 23550 COMPLETED----------------	Time Elapsed: 16.77980875968933 seconds
# USER 23600 COMPLETED----------------	Time Elapsed: 13.50082516670227 seconds
# USER 23650 COMPLETED----------------	Time Elapsed: 8.619274139404297 seconds
# USER 23700 COMPLETED----------------	Time Elapsed: 19.0240740776062 seconds
# USER 23750 COMPLETED----------------	Time Elapsed: 11.090865135192871 seconds
# USER 23800 COMPLETED----------------	Time Elapsed: 10.562594175338745 seconds
# USER 23850 COMPLETED----------------	Time Elapsed: 8.89619779586792 seconds
# USER 23900 COMPLETED----------------	Time Elapsed: 15.214755296707153 seconds
# USER 23950 COMPLETED----------------	Time Elapsed: 9.65886402130127 seconds
# USER 24000 COMPLETED----------------	Time Elapsed: 10.954657077789307 seconds
# USER 24050 COMPLETED----------------	Time Elapsed: 13.901793718338013 seconds
# USER 24100 COMPLETED----------------	Time Elapsed: 11.939834117889404 seconds
# USER 24150 COMPLETED----------------	Time Elapsed: 9.730454921722412 seconds
# USER 24200 COMPLETED----------------	Time Elapsed: 12.460358142852783 seconds
# USER 24250 COMPLETED----------------	Time Elapsed: 7.954764127731323 seconds
# USER 24300 COMPLETED----------------	Time Elapsed: 25.30727982521057 seconds
# USER 24350 COMPLETED----------------	Time Elapsed: 10.398646116256714 seconds
# USER 24400 COMPLETED----------------	Time Elapsed: 7.908614158630371 seconds
# USER 24450 COMPLETED----------------	Time Elapsed: 7.4999589920043945 seconds
# USER 24500 COMPLETED----------------	Time Elapsed: 10.814253807067871 seconds
# USER 24550 COMPLETED----------------	Time Elapsed: 9.934489965438843 seconds
# USER 24600 COMPLETED----------------	Time Elapsed: 23.739230155944824 seconds
# USER 24650 COMPLETED----------------	Time Elapsed: 7.164005279541016 seconds
# USER 24700 COMPLETED----------------	Time Elapsed: 12.550177812576294 seconds
# USER 24750 COMPLETED----------------	Time Elapsed: 9.479365110397339 seconds
# USER 24800 COMPLETED----------------	Time Elapsed: 10.175829887390137 seconds
# USER 24850 COMPLETED----------------	Time Elapsed: 7.217936038970947 seconds
# USER 24900 COMPLETED----------------	Time Elapsed: 9.70757794380188 seconds
# USER 24950 COMPLETED----------------	Time Elapsed: 7.969817876815796 seconds
# USER 25000 COMPLETED----------------	Time Elapsed: 8.557269096374512 seconds
# USER 25050 COMPLETED----------------	Time Elapsed: 11.16663908958435 seconds
# USER 25100 COMPLETED----------------	Time Elapsed: 6.5746049880981445 seconds
# USER 25150 COMPLETED----------------	Time Elapsed: 6.33571195602417 seconds
# USER 25200 COMPLETED----------------	Time Elapsed: 8.842694759368896 seconds
# USER 25250 COMPLETED----------------	Time Elapsed: 9.81275987625122 seconds
# USER 25300 COMPLETED----------------	Time Elapsed: 9.069792985916138 seconds
# USER 25350 COMPLETED----------------	Time Elapsed: 9.762505054473877 seconds
# USER 25400 COMPLETED----------------	Time Elapsed: 14.815995931625366 seconds
# USER 25450 COMPLETED----------------	Time Elapsed: 12.138732194900513 seconds
# USER 25500 COMPLETED----------------	Time Elapsed: 6.781670808792114 seconds
# USER 25550 COMPLETED----------------	Time Elapsed: 7.534542083740234 seconds
# USER 25600 COMPLETED----------------	Time Elapsed: 8.186979055404663 seconds
# USER 25650 COMPLETED----------------	Time Elapsed: 16.167484283447266 seconds
# USER 25700 COMPLETED----------------	Time Elapsed: 7.5887298583984375 seconds
# USER 25750 COMPLETED----------------	Time Elapsed: 9.38852310180664 seconds
# USER 25800 COMPLETED----------------	Time Elapsed: 7.691617012023926 seconds
# USER 25850 COMPLETED----------------	Time Elapsed: 11.389864921569824 seconds
# USER 25900 COMPLETED----------------	Time Elapsed: 7.412177085876465 seconds
# USER 25950 COMPLETED----------------	Time Elapsed: 19.01253890991211 seconds
# USER 26000 COMPLETED----------------	Time Elapsed: 7.178739309310913 seconds
# USER 26050 COMPLETED----------------	Time Elapsed: 7.946567058563232 seconds
# USER 26100 COMPLETED----------------	Time Elapsed: 9.120574951171875 seconds
# USER 26150 COMPLETED----------------	Time Elapsed: 9.836623191833496 seconds
# USER 26200 COMPLETED----------------	Time Elapsed: 6.964471817016602 seconds
# USER 26250 COMPLETED----------------	Time Elapsed: 10.033058881759644 seconds
# USER 26300 COMPLETED----------------	Time Elapsed: 9.300044775009155 seconds
# USER 26350 COMPLETED----------------	Time Elapsed: 8.818359136581421 seconds
# USER 26400 COMPLETED----------------	Time Elapsed: 8.862663984298706 seconds
# USER 26450 COMPLETED----------------	Time Elapsed: 11.966440200805664 seconds
# USER 26500 COMPLETED----------------	Time Elapsed: 6.628273963928223 seconds
# USER 26550 COMPLETED----------------	Time Elapsed: 12.570686101913452 seconds
# USER 26600 COMPLETED----------------	Time Elapsed: 10.234539031982422 seconds
# USER 26650 COMPLETED----------------	Time Elapsed: 12.761066198348999 seconds
# USER 26700 COMPLETED----------------	Time Elapsed: 15.020666122436523 seconds
# USER 26750 COMPLETED----------------	Time Elapsed: 25.029783964157104 seconds
# USER 26800 COMPLETED----------------	Time Elapsed: 9.194246292114258 seconds
# USER 26850 COMPLETED----------------	Time Elapsed: 19.520540952682495 seconds
# USER 26900 COMPLETED----------------	Time Elapsed: 9.068002223968506 seconds
# USER 26950 COMPLETED----------------	Time Elapsed: 8.02798080444336 seconds
# USER 27000 COMPLETED----------------	Time Elapsed: 8.361509323120117 seconds
# USER 27050 COMPLETED----------------	Time Elapsed: 13.904495239257812 seconds
# USER 27100 COMPLETED----------------	Time Elapsed: 17.005106210708618 seconds
# USER 27150 COMPLETED----------------	Time Elapsed: 20.941018104553223 seconds
# USER 27200 COMPLETED----------------	Time Elapsed: 24.204602003097534 seconds
# USER 27250 COMPLETED----------------	Time Elapsed: 8.861519813537598 seconds
# USER 27300 COMPLETED----------------	Time Elapsed: 7.664819955825806 seconds
# USER 27350 COMPLETED----------------	Time Elapsed: 8.591194152832031 seconds
# USER 27400 COMPLETED----------------	Time Elapsed: 8.12588381767273 seconds
# USER 27450 COMPLETED----------------	Time Elapsed: 11.004974126815796 seconds
# USER 27500 COMPLETED----------------	Time Elapsed: 6.551868915557861 seconds
# USER 27550 COMPLETED----------------	Time Elapsed: 7.3857409954071045 seconds
# USER 27600 COMPLETED----------------	Time Elapsed: 8.462072849273682 seconds
# USER 27650 COMPLETED----------------	Time Elapsed: 20.181677103042603 seconds
# USER 27700 COMPLETED----------------	Time Elapsed: 16.966537952423096 seconds
# USER 27750 COMPLETED----------------	Time Elapsed: 11.676990985870361 seconds
# USER 27800 COMPLETED----------------	Time Elapsed: 17.402970790863037 seconds
# USER 27850 COMPLETED----------------	Time Elapsed: 13.126949787139893 seconds
# USER 27900 COMPLETED----------------	Time Elapsed: 9.239517211914062 seconds
# USER 27950 COMPLETED----------------	Time Elapsed: 10.357898950576782 seconds
# USER 28000 COMPLETED----------------	Time Elapsed: 9.667041063308716 seconds
# USER 28050 COMPLETED----------------	Time Elapsed: 11.92577600479126 seconds
# USER 28100 COMPLETED----------------	Time Elapsed: 9.499638080596924 seconds
# USER 28150 COMPLETED----------------	Time Elapsed: 10.235536813735962 seconds
# USER 28200 COMPLETED----------------	Time Elapsed: 8.36056113243103 seconds
# USER 28250 COMPLETED----------------	Time Elapsed: 12.087929964065552 seconds
# USER 28300 COMPLETED----------------	Time Elapsed: 21.09246301651001 seconds
# USER 28350 COMPLETED----------------	Time Elapsed: 13.855069875717163 seconds
# USER 28400 COMPLETED----------------	Time Elapsed: 13.838818073272705 seconds
# USER 28450 COMPLETED----------------	Time Elapsed: 21.647429943084717 seconds
# USER 28500 COMPLETED----------------	Time Elapsed: 10.905749082565308 seconds
# USER 28550 COMPLETED----------------	Time Elapsed: 13.369163036346436 seconds
# USER 28600 COMPLETED----------------	Time Elapsed: 12.086310148239136 seconds
# USER 28650 COMPLETED----------------	Time Elapsed: 15.192227840423584 seconds
# USER 28700 COMPLETED----------------	Time Elapsed: 13.074575901031494 seconds
# USER 28750 COMPLETED----------------	Time Elapsed: 10.431679964065552 seconds
# USER 28800 COMPLETED----------------	Time Elapsed: 10.403661966323853 seconds
# USER 28850 COMPLETED----------------	Time Elapsed: 10.649816989898682 seconds
# USER 28900 COMPLETED----------------	Time Elapsed: 9.892470121383667 seconds
# USER 28950 COMPLETED----------------	Time Elapsed: 9.923896074295044 seconds
# USER 29000 COMPLETED----------------	Time Elapsed: 11.20170783996582 seconds
# USER 29050 COMPLETED----------------	Time Elapsed: 8.323155879974365 seconds
# USER 29100 COMPLETED----------------	Time Elapsed: 8.373481273651123 seconds
# USER 29150 COMPLETED----------------	Time Elapsed: 9.364702939987183 seconds
# USER 29200 COMPLETED----------------	Time Elapsed: 14.056344032287598 seconds
# USER 29250 COMPLETED----------------	Time Elapsed: 10.842272758483887 seconds
# USER 29300 COMPLETED----------------	Time Elapsed: 26.307302951812744 seconds
# USER 29350 COMPLETED----------------	Time Elapsed: 15.076265335083008 seconds
# USER 29400 COMPLETED----------------	Time Elapsed: 6.827562093734741 seconds
# USER 29450 COMPLETED----------------	Time Elapsed: 7.928367853164673 seconds
# USER 29500 COMPLETED----------------	Time Elapsed: 16.476505994796753 seconds
# USER 29550 COMPLETED----------------	Time Elapsed: 9.424284219741821 seconds
# USER 29600 COMPLETED----------------	Time Elapsed: 9.582435131072998 seconds
# USER 29650 COMPLETED----------------	Time Elapsed: 16.11618995666504 seconds
# USER 29700 COMPLETED----------------	Time Elapsed: 9.077898979187012 seconds
# USER 29750 COMPLETED----------------	Time Elapsed: 8.180639028549194 seconds
# USER 29800 COMPLETED----------------	Time Elapsed: 7.13058614730835 seconds
# USER 29850 COMPLETED----------------	Time Elapsed: 9.245512247085571 seconds
# USER 29900 COMPLETED----------------	Time Elapsed: 12.236583948135376 seconds
# USER 29950 COMPLETED----------------	Time Elapsed: 8.236992120742798 seconds
# USER 30000 COMPLETED----------------	Time Elapsed: 6.97825288772583 seconds
# USER 30050 COMPLETED----------------	Time Elapsed: 8.987516164779663 seconds
# USER 30100 COMPLETED----------------	Time Elapsed: 11.777749061584473 seconds
# USER 30150 COMPLETED----------------	Time Elapsed: 11.793599128723145 seconds
# USER 30200 COMPLETED----------------	Time Elapsed: 6.602630138397217 seconds
# USER 30250 COMPLETED----------------	Time Elapsed: 10.130254983901978 seconds
# USER 30300 COMPLETED----------------	Time Elapsed: 14.577905178070068 seconds
# USER 30350 COMPLETED----------------	Time Elapsed: 10.158203840255737 seconds
# USER 30400 COMPLETED----------------	Time Elapsed: 12.431464910507202 seconds
# USER 30450 COMPLETED----------------	Time Elapsed: 7.639846086502075 seconds
# USER 30500 COMPLETED----------------	Time Elapsed: 12.040621995925903 seconds
# USER 30550 COMPLETED----------------	Time Elapsed: 9.99694013595581 seconds
# USER 30600 COMPLETED----------------	Time Elapsed: 9.945355892181396 seconds
# USER 30650 COMPLETED----------------	Time Elapsed: 10.866854906082153 seconds
# USER 30700 COMPLETED----------------	Time Elapsed: 13.350389003753662 seconds
# USER 30750 COMPLETED----------------	Time Elapsed: 13.335225105285645 seconds
# USER 30800 COMPLETED----------------	Time Elapsed: 10.015439987182617 seconds
# USER 30850 COMPLETED----------------	Time Elapsed: 8.18959093093872 seconds
# USER 30900 COMPLETED----------------	Time Elapsed: 13.36044192314148 seconds
# USER 30950 COMPLETED----------------	Time Elapsed: 9.691461086273193 seconds
# USER 31000 COMPLETED----------------	Time Elapsed: 24.922204971313477 seconds
# USER 31050 COMPLETED----------------	Time Elapsed: 7.449517011642456 seconds
# USER 31100 COMPLETED----------------	Time Elapsed: 10.30637001991272 seconds
# ...
# USER 383500 COMPLETED----------------	Time Elapsed: 11.419039964675903 seconds
# USER 383550 COMPLETED----------------	Time Elapsed: 23.390309810638428 seconds
# USER 383600 COMPLETED----------------	Time Elapsed: 11.866371870040894 seconds
# USER 383650 COMPLETED----------------	Time Elapsed: 8.625080108642578 seconds
# USER 383700 COMPLETED----------------	Time Elapsed: 13.675110101699829 seconds
# USER 383750 COMPLETED----------------	Time Elapsed: 7.9862871170043945 seconds
# USER 383800 COMPLETED----------------	Time Elapsed: 7.805686712265015 seconds
# USER 383850 COMPLETED----------------	Time Elapsed: 9.00189733505249 seconds
# USER 383900 COMPLETED----------------	Time Elapsed: 10.945075273513794 seconds
# USER 383950 COMPLETED----------------	Time Elapsed: 11.08419919013977 seconds
# USER 384000 COMPLETED----------------	Time Elapsed: 17.994971752166748 seconds
# USER 384050 COMPLETED----------------	Time Elapsed: 10.112497091293335 seconds
# USER 384100 COMPLETED----------------	Time Elapsed: 10.424117803573608 seconds
# USER 384150 COMPLETED----------------	Time Elapsed: 11.364212036132812 seconds
# USER 384200 COMPLETED----------------	Time Elapsed: 7.740116119384766 seconds
# USER 384250 COMPLETED----------------	Time Elapsed: 10.013187885284424 seconds
# USER 384300 COMPLETED----------------	Time Elapsed: 10.408167839050293 seconds
# USER 384350 COMPLETED----------------	Time Elapsed: 12.24687910079956 seconds
# USER 384400 COMPLETED----------------	Time Elapsed: 10.897765159606934 seconds
# USER 384450 COMPLETED----------------	Time Elapsed: 8.233990907669067 seconds
# USER 384500 COMPLETED----------------	Time Elapsed: 10.626148700714111 seconds
# USER 384550 COMPLETED----------------	Time Elapsed: 11.189743757247925 seconds
# USER 384600 COMPLETED----------------	Time Elapsed: 13.45936107635498 seconds
# USER 384650 COMPLETED----------------	Time Elapsed: 7.075939178466797 seconds
# USER 384700 COMPLETED----------------	Time Elapsed: 12.307873010635376 seconds
# USER 384750 COMPLETED----------------	Time Elapsed: 10.874308109283447 seconds
# USER 384800 COMPLETED----------------	Time Elapsed: 11.940014839172363 seconds
# USER 384850 COMPLETED----------------	Time Elapsed: 11.00976300239563 seconds
# USER 384900 COMPLETED----------------	Time Elapsed: 10.245859146118164 seconds
# USER 384950 COMPLETED----------------	Time Elapsed: 9.035243034362793 seconds
# USER 385000 COMPLETED----------------	Time Elapsed: 8.240816116333008 seconds
# USER 385050 COMPLETED----------------	Time Elapsed: 7.679680109024048 seconds
# USER 385100 COMPLETED----------------	Time Elapsed: 18.32546615600586 seconds
# USER 385150 COMPLETED----------------	Time Elapsed: 8.833925008773804 seconds
# USER 385200 COMPLETED----------------	Time Elapsed: 23.12808394432068 seconds
# USER 385250 COMPLETED----------------	Time Elapsed: 20.662485122680664 seconds
# USER 385300 COMPLETED----------------	Time Elapsed: 9.167128086090088 seconds
# USER 385350 COMPLETED----------------	Time Elapsed: 11.898386001586914 seconds
# USER 385400 COMPLETED----------------	Time Elapsed: 10.412477016448975 seconds
# USER 385450 COMPLETED----------------	Time Elapsed: 18.10353398323059 seconds
# USER 385500 COMPLETED----------------	Time Elapsed: 10.0452139377594 seconds
# USER 385550 COMPLETED----------------	Time Elapsed: 9.97231912612915 seconds
# USER 385600 COMPLETED----------------	Time Elapsed: 21.674098253250122 seconds
# USER 385650 COMPLETED----------------	Time Elapsed: 12.578194856643677 seconds
# USER 385700 COMPLETED----------------	Time Elapsed: 9.718200206756592 seconds
# USER 385750 COMPLETED----------------	Time Elapsed: 8.931846141815186 seconds
# USER 385800 COMPLETED----------------	Time Elapsed: 10.33165192604065 seconds
# USER 385850 COMPLETED----------------	Time Elapsed: 10.986295938491821 seconds
# USER 385900 COMPLETED----------------	Time Elapsed: 10.698134183883667 seconds
# USER 385950 COMPLETED----------------	Time Elapsed: 20.442833185195923 seconds
# USER 386000 COMPLETED----------------	Time Elapsed: 9.23039698600769 seconds
# USER 386050 COMPLETED----------------	Time Elapsed: 11.120492935180664 seconds
# USER 386100 COMPLETED----------------	Time Elapsed: 8.181199073791504 seconds
# USER 386150 COMPLETED----------------	Time Elapsed: 9.767753839492798 seconds
# USER 386200 COMPLETED----------------	Time Elapsed: 8.910166025161743 seconds
# USER 386250 COMPLETED----------------	Time Elapsed: 8.305479049682617 seconds
# USER 386300 COMPLETED----------------	Time Elapsed: 10.39962100982666 seconds
# USER 386350 COMPLETED----------------	Time Elapsed: 11.061055898666382 seconds
# USER 386400 COMPLETED----------------	Time Elapsed: 37.03749227523804 seconds
# USER 386450 COMPLETED----------------	Time Elapsed: 13.011879205703735 seconds
# USER 386500 COMPLETED----------------	Time Elapsed: 14.874390840530396 seconds
# USER 386550 COMPLETED----------------	Time Elapsed: 12.067873001098633 seconds
# USER 386600 COMPLETED----------------	Time Elapsed: 8.221556901931763 seconds
# USER 386650 COMPLETED----------------	Time Elapsed: 7.390795707702637 seconds
# USER 386700 COMPLETED----------------	Time Elapsed: 12.530143976211548 seconds
# USER 386750 COMPLETED----------------	Time Elapsed: 10.703415870666504 seconds
# USER 386800 COMPLETED----------------	Time Elapsed: 9.938345909118652 seconds
# USER 386850 COMPLETED----------------	Time Elapsed: 7.6138999462127686 seconds
# USER 386900 COMPLETED----------------	Time Elapsed: 9.70967698097229 seconds
# USER 386950 COMPLETED----------------	Time Elapsed: 9.725767135620117 seconds
# USER 387000 COMPLETED----------------	Time Elapsed: 9.889027833938599 seconds
# USER 387050 COMPLETED----------------	Time Elapsed: 10.313549041748047 seconds
# USER 387100 COMPLETED----------------	Time Elapsed: 6.833467960357666 seconds
# USER 387150 COMPLETED----------------	Time Elapsed: 12.77776288986206 seconds
# USER 387200 COMPLETED----------------	Time Elapsed: 8.774641752243042 seconds
# USER 387250 COMPLETED----------------	Time Elapsed: 12.245376110076904 seconds
# USER 387300 COMPLETED----------------	Time Elapsed: 9.672594785690308 seconds
# USER 387350 COMPLETED----------------	Time Elapsed: 8.037617921829224 seconds
# USER 387400 COMPLETED----------------	Time Elapsed: 7.253235101699829 seconds
# USER 387450 COMPLETED----------------	Time Elapsed: 8.508517265319824 seconds
# USER 387500 COMPLETED----------------	Time Elapsed: 10.626266956329346 seconds
# USER 387550 COMPLETED----------------	Time Elapsed: 7.51430082321167 seconds
# USER 387600 COMPLETED----------------	Time Elapsed: 13.227457046508789 seconds
# USER 387650 COMPLETED----------------	Time Elapsed: 8.76528787612915 seconds
# USER 387700 COMPLETED----------------	Time Elapsed: 6.566070079803467 seconds
# USER 387750 COMPLETED----------------	Time Elapsed: 11.653110980987549 seconds
# USER 387800 COMPLETED----------------	Time Elapsed: 12.931227922439575 seconds
# USER 387850 COMPLETED----------------	Time Elapsed: 9.872631072998047 seconds
# USER 387900 COMPLETED----------------	Time Elapsed: 9.603058815002441 seconds
# USER 387950 COMPLETED----------------	Time Elapsed: 14.827837944030762 seconds
# USER 388000 COMPLETED----------------	Time Elapsed: 9.70243215560913 seconds
# USER 388050 COMPLETED----------------	Time Elapsed: 26.15828824043274 seconds
# USER 388100 COMPLETED----------------	Time Elapsed: 8.850085973739624 seconds
# USER 388150 COMPLETED----------------	Time Elapsed: 5.940975904464722 seconds
# USER 388200 COMPLETED----------------	Time Elapsed: 11.4753999710083 seconds
# USER 388250 COMPLETED----------------	Time Elapsed: 22.809159994125366 seconds
# USER 388300 COMPLETED----------------	Time Elapsed: 12.236708879470825 seconds
# USER 388350 COMPLETED----------------	Time Elapsed: 10.362020015716553 seconds
# USER 388400 COMPLETED----------------	Time Elapsed: 8.339173793792725 seconds
# USER 388450 COMPLETED----------------	Time Elapsed: 14.594787120819092 seconds
# USER 388500 COMPLETED----------------	Time Elapsed: 11.408596992492676 seconds
# USER 388550 COMPLETED----------------	Time Elapsed: 25.63501000404358 seconds
# USER 388600 COMPLETED----------------	Time Elapsed: 19.639491081237793 seconds
# USER 388650 COMPLETED----------------	Time Elapsed: 10.17763876914978 seconds
# USER 388700 COMPLETED----------------	Time Elapsed: 9.320182085037231 seconds
# USER 388750 COMPLETED----------------	Time Elapsed: 8.744022130966187 seconds
# USER 388800 COMPLETED----------------	Time Elapsed: 18.908525943756104 seconds
# USER 388850 COMPLETED----------------	Time Elapsed: 6.9517247676849365 seconds
# USER 388900 COMPLETED----------------	Time Elapsed: 11.290605068206787 seconds
# USER 388950 COMPLETED----------------	Time Elapsed: 6.842819690704346 seconds
# USER 389000 COMPLETED----------------	Time Elapsed: 7.790181875228882 seconds
# USER 389050 COMPLETED----------------	Time Elapsed: 7.524935960769653 seconds
# USER 389100 COMPLETED----------------	Time Elapsed: 15.600786924362183 seconds
# USER 389150 COMPLETED----------------	Time Elapsed: 8.597508907318115 seconds
# USER 389200 COMPLETED----------------	Time Elapsed: 11.86085295677185 seconds
# USER 389250 COMPLETED----------------	Time Elapsed: 9.065943002700806 seconds
# USER 389300 COMPLETED----------------	Time Elapsed: 8.300270795822144 seconds
# USER 389350 COMPLETED----------------	Time Elapsed: 22.6923189163208 seconds
# USER 389400 COMPLETED----------------	Time Elapsed: 10.776031970977783 seconds
# USER 389450 COMPLETED----------------	Time Elapsed: 9.622354984283447 seconds
# USER 389500 COMPLETED----------------	Time Elapsed: 9.041018009185791 seconds
# USER 389550 COMPLETED----------------	Time Elapsed: 10.899276971817017 seconds
# USER 389600 COMPLETED----------------	Time Elapsed: 10.227755069732666 seconds
# USER 389650 COMPLETED----------------	Time Elapsed: 19.38477396965027 seconds
# USER 389700 COMPLETED----------------	Time Elapsed: 22.620816946029663 seconds
# USER 389750 COMPLETED----------------	Time Elapsed: 12.203510999679565 seconds
# USER 389800 COMPLETED----------------	Time Elapsed: 16.041968822479248 seconds
# USER 389850 COMPLETED----------------	Time Elapsed: 8.311078786849976 seconds
# USER 389900 COMPLETED----------------	Time Elapsed: 10.676905155181885 seconds
# USER 389950 COMPLETED----------------	Time Elapsed: 9.955733060836792 seconds
# USER 390000 COMPLETED----------------	Time Elapsed: 12.945350885391235 seconds
# USER 390050 COMPLETED----------------	Time Elapsed: 7.1528480052948 seconds
# USER 390100 COMPLETED----------------	Time Elapsed: 7.7842607498168945 seconds
# USER 390150 COMPLETED----------------	Time Elapsed: 13.469578981399536 seconds
# USER 390200 COMPLETED----------------	Time Elapsed: 10.861100196838379 seconds
# USER 390250 COMPLETED----------------	Time Elapsed: 6.527237892150879 seconds
# USER 390300 COMPLETED----------------	Time Elapsed: 8.965322017669678 seconds
# USER 390350 COMPLETED----------------	Time Elapsed: 6.923804998397827 seconds
# USER 390400 COMPLETED----------------	Time Elapsed: 9.189585208892822 seconds
# USER 390450 COMPLETED----------------	Time Elapsed: 10.766087055206299 seconds
# USER 390500 COMPLETED----------------	Time Elapsed: 9.956913948059082 seconds
# USER 390550 COMPLETED----------------	Time Elapsed: 11.756470918655396 seconds
# USER 390600 COMPLETED----------------	Time Elapsed: 9.487595081329346 seconds
# USER 390650 COMPLETED----------------	Time Elapsed: 8.773170948028564 seconds
# USER 390700 COMPLETED----------------	Time Elapsed: 7.976976156234741 seconds
# USER 390750 COMPLETED----------------	Time Elapsed: 9.317357778549194 seconds
# USER 390800 COMPLETED----------------	Time Elapsed: 11.488826990127563 seconds
# USER 390850 COMPLETED----------------	Time Elapsed: 10.10732126235962 seconds
# USER 390900 COMPLETED----------------	Time Elapsed: 32.54182314872742 seconds
# USER 390950 COMPLETED----------------	Time Elapsed: 19.709259748458862 seconds
# USER 391000 COMPLETED----------------	Time Elapsed: 8.117753028869629 seconds
# USER 391050 COMPLETED----------------	Time Elapsed: 9.616226196289062 seconds
# USER 391100 COMPLETED----------------	Time Elapsed: 11.474416017532349 seconds
# USER 391150 COMPLETED----------------	Time Elapsed: 7.899028062820435 seconds
# USER 391200 COMPLETED----------------	Time Elapsed: 11.127758026123047 seconds
# USER 391250 COMPLETED----------------	Time Elapsed: 14.736427783966064 seconds
# USER 391300 COMPLETED----------------	Time Elapsed: 14.826043844223022 seconds
# USER 391350 COMPLETED----------------	Time Elapsed: 11.826000213623047 seconds
# USER 391400 COMPLETED----------------	Time Elapsed: 9.010459184646606 seconds
# USER 391450 COMPLETED----------------	Time Elapsed: 8.051340103149414 seconds
# USER 391500 COMPLETED----------------	Time Elapsed: 8.533245086669922 seconds
# USER 391550 COMPLETED----------------	Time Elapsed: 32.51628279685974 seconds
# USER 391600 COMPLETED----------------	Time Elapsed: 9.253916263580322 seconds
# USER 391650 COMPLETED----------------	Time Elapsed: 17.324997901916504 seconds
# USER 391700 COMPLETED----------------	Time Elapsed: 11.606613159179688 seconds
# USER 391750 COMPLETED----------------	Time Elapsed: 10.949473142623901 seconds
# USER 391800 COMPLETED----------------	Time Elapsed: 11.228490114212036 seconds
# USER 391850 COMPLETED----------------	Time Elapsed: 9.279161930084229 seconds
# USER 391900 COMPLETED----------------	Time Elapsed: 9.351383209228516 seconds
# USER 391950 COMPLETED----------------	Time Elapsed: 9.480073928833008 seconds
# USER 392000 COMPLETED----------------	Time Elapsed: 25.496013879776 seconds
# USER 392050 COMPLETED----------------	Time Elapsed: 8.285881757736206 seconds
# USER 392100 COMPLETED----------------	Time Elapsed: 20.45667290687561 seconds
# USER 392150 COMPLETED----------------	Time Elapsed: 30.063750743865967 seconds
# USER 392200 COMPLETED----------------	Time Elapsed: 9.829642057418823 seconds
# USER 392250 COMPLETED----------------	Time Elapsed: 14.02824878692627 seconds
# USER 392300 COMPLETED----------------	Time Elapsed: 17.43345594406128 seconds
# USER 392350 COMPLETED----------------	Time Elapsed: 7.571274042129517 seconds
# USER 392400 COMPLETED----------------	Time Elapsed: 11.518160343170166 seconds
# USER 392450 COMPLETED----------------	Time Elapsed: 8.752464056015015 seconds
# USER 392500 COMPLETED----------------	Time Elapsed: 12.32239317893982 seconds
# USER 392550 COMPLETED----------------	Time Elapsed: 24.379899263381958 seconds
# USER 392600 COMPLETED----------------	Time Elapsed: 8.25273609161377 seconds
# USER 392650 COMPLETED----------------	Time Elapsed: 10.345470190048218 seconds
# USER 392700 COMPLETED----------------	Time Elapsed: 17.674721002578735 seconds
# USER 392750 COMPLETED----------------	Time Elapsed: 14.395191669464111 seconds
# USER 392800 COMPLETED----------------	Time Elapsed: 8.661035060882568 seconds
# USER 392850 COMPLETED----------------	Time Elapsed: 8.030214071273804 seconds
# USER 392900 COMPLETED----------------	Time Elapsed: 11.471129894256592 seconds
# USER 392950 COMPLETED----------------	Time Elapsed: 7.694536924362183 seconds
# USER 393000 COMPLETED----------------	Time Elapsed: 8.922926187515259 seconds
# USER 393050 COMPLETED----------------	Time Elapsed: 15.664881944656372 seconds
# USER 393100 COMPLETED----------------	Time Elapsed: 8.019180059432983 seconds
# USER 393150 COMPLETED----------------	Time Elapsed: 22.55781888961792 seconds
# USER 393200 COMPLETED----------------	Time Elapsed: 22.681263208389282 seconds
# USER 393250 COMPLETED----------------	Time Elapsed: 14.08963680267334 seconds
# USER 393300 COMPLETED----------------	Time Elapsed: 9.804017782211304 seconds
# USER 393350 COMPLETED----------------	Time Elapsed: 8.429538011550903 seconds
# USER 393400 COMPLETED----------------	Time Elapsed: 12.393209218978882 seconds
# USER 393450 COMPLETED----------------	Time Elapsed: 28.190814971923828 seconds
# USER 393500 COMPLETED----------------	Time Elapsed: 11.964586973190308 seconds
# USER 393550 COMPLETED----------------	Time Elapsed: 14.276174068450928 seconds
# USER 393600 COMPLETED----------------	Time Elapsed: 17.74938201904297 seconds
# USER 393650 COMPLETED----------------	Time Elapsed: 9.976152896881104 seconds

# %%
# save params to json
with open('skill_params.json', 'w') as json_file:
    json.dump(params, json_file)

# %%
params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bfd368200e6b> in <module>
# ----> 1 params
#
# NameError: name 'params' is not defined
